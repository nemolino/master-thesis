# %%
import logging
import pickle
import numpy as np

# %%
#from instance import Instance, InfeasibleOnBuilding
from FINAL_src_CG_basic_PureDiving import ColumnGeneration
from FINAL_src_CG_basic_PureDiving_new import ColumnGeneration

# %%
def setup_logger(name, log_file, level):

    formatter = logging.Formatter('%(levelname)s %(message)s')
    handler = logging.FileHandler(log_file, mode='w')        
    handler.setFormatter(formatter)

    logger = logging.getLogger(name)
    logger.setLevel(level)
    logger.addHandler(handler)

    return logger

# %%
with open('instances_dataset_FINAL.pickle', 'rb') as f:
   instances = pickle.load(f)

with open('rnr_feasible_instances_indexes.pickle', 'rb') as f:
   indexes = pickle.load(f)

# %%
for network_size in indexes:
        
    for idx in indexes[network_size]:

        i = instances[idx]

        network_filename, network_rp_filename, app_merged, app_merged_rp, app_filenames, app_rp_filenames = i
        print(f"{idx} {len(app_filenames)} apps, {network_rp_filename} {app_merged}")
        

        # try:
        #     instance = Instance.build(
        #         network_filename, 
        #         network_rp_filename, 
        #         app_merged, 
        #         app_merged_rp
        #     )
        # except InfeasibleOnBuilding:
        #     print("INFEASIBLE on building")
        #     continue

        
        logger = setup_logger(f"logger_{idx:03d}", f"logs/id_{idx:04d}.log", logging.DEBUG)
        
        try:
            cg = ColumnGeneration(
                N= len(app_filenames),
                filenames= (
                    network_filename, network_rp_filename, 
                    app_filenames, app_rp_filenames
                ),
                logger= logger
            )
            # result = cg.execute()
            cg.execute()
        except Exception as e:
            print(f"ERROR in ColumnGeneration : {e}")
            raise RuntimeError()
        
        
        # print()
        # print(f"dual {result[0]} primal {result[1]}")

        # CG_DUAL_BOUND[idx] = result[0]
        # CG_PRIMAL_BOUND[idx] = result[1]
        # CG_TIME[idx] = result[2]
    
        print("\n" + "-" * 80 + "\n")
# Out:
# 0 2 apps, DATASET_2/networks/network_030_a_rp_0.dat DATASET_2/apps_merged_FINAL/id_0000.dat
#
# STOP, gap < 0.1 %
# #iterations 3 LR_dual_bound 410.27598322566024 CG_time 0.230
#
# PureDiving
#
# most selected pattern : app 0 pattern 1 with value 0.8329744229098189
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 429.0 0.014
#
# --------------------------------------------------------------------------------
#
# 1 2 apps, DATASET_2/networks/network_030_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0001.dat
#
# STOP, gap < 0.1 %
# #iterations 6 LR_dual_bound 570.2159775190687 CG_time 0.186
#
# PureDiving
#
# most selected pattern : app 1 pattern 5 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 573.0 0.003
#
# --------------------------------------------------------------------------------
#
# 2 2 apps, DATASET_2/networks/network_030_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0002.dat
#
# STOP, gap < 0.1 %
# #iterations 8 LR_dual_bound 940.6254739034483 CG_time 0.613
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 0.5782640057706178
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 990.0 0.044
#
# --------------------------------------------------------------------------------
#
# 3 3 apps, DATASET_2/networks/network_030_c_rp_0.dat DATASET_2/apps_merged_FINAL/id_0003.dat
#
# STOP, gap < 0.1 %
# #iterations 6 LR_dual_bound 695.2447040450787 CG_time 0.576
#
# PureDiving
#
# most selected pattern : app 1 pattern 5 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 710.0 0.155
#
# --------------------------------------------------------------------------------
#
# 4 3 apps, DATASET_2/networks/network_030_a_rp_3.dat DATASET_2/apps_merged_FINAL/id_0004.dat
#
# STOP, gap < 0.1 %
# #iterations 3 LR_dual_bound 804.392432864131 CG_time 0.254
#
# PureDiving
#
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 808.0 0.021
#
# --------------------------------------------------------------------------------
#
# 5 3 apps, DATASET_2/networks/network_030_c_rp_4.dat DATASET_2/apps_merged_FINAL/id_0005.dat
#
# STOP, gap < 0.1 %
# #iterations 8 LR_dual_bound 957.993672909767 CG_time 1.691
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 0.8536324563778892
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 4 with value 0.8129316500311441
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 998.0 0.193
#
# --------------------------------------------------------------------------------
#
# 6 4 apps, DATASET_2/networks/network_030_a_rp_1.dat DATASET_2/apps_merged_FINAL/id_0006.dat
#
# STOP, gap < 0.1 %
# #iterations 12 LR_dual_bound 1373.4126999511518 CG_time 2.966
#
# PureDiving
#
# most selected pattern : app 1 pattern 5 with value 0.8851107657066369
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 2 with value 0.9185695754282236
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 3 with value 0.6356185284911742
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1436.0 0.413
#
# --------------------------------------------------------------------------------
#
# 7 4 apps, DATASET_2/networks/network_030_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0007.dat
#
# STOP, gap < 0.1 %
# #iterations 8 LR_dual_bound 1084.5926812886041 CG_time 1.013
#
# PureDiving
#
# most selected pattern : app 0 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1116.0 0.151
#
# --------------------------------------------------------------------------------
#
# 8 4 apps, DATASET_2/networks/network_030_d_rp_2.dat DATASET_2/apps_merged_FINAL/id_0008.dat
#
# STOP, gap < 0.1 %
# #iterations 14 LR_dual_bound 1645.137137862996 CG_time 4.316
#
# PureDiving
#
# most selected pattern : app 0 pattern 7 with value 0.79179881234958
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 5 with value 0.5946508783265961
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 1 pattern 1 with value 0.8271126727595925
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1704.0 0.516
#
# --------------------------------------------------------------------------------
#
# 9 5 apps, DATASET_2/networks/network_030_c_rp_4.dat DATASET_2/apps_merged_FINAL/id_0009.dat
#
# STOP, gap < 0.1 %
# #iterations 19 LR_dual_bound 1960.4730401295872 CG_time 6.167
#
# PureDiving
#
# most selected pattern : app 1 pattern 7 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 10 with value 0.6668086237320182
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 1 with value 0.5180474218654073
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 4 pattern 2 with value 0.6936416184971096
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2067.0 0.984
#
# --------------------------------------------------------------------------------
#
# 10 5 apps, DATASET_2/networks/network_030_a_rp_3.dat DATASET_2/apps_merged_FINAL/id_0010.dat
#
# STOP, gap < 0.1 %
# #iterations 15 LR_dual_bound 1728.0944454958621 CG_time 3.965
#
# PureDiving
#
# most selected pattern : app 1 pattern 13 with value 0.728813559322034
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 3 with value 0.7071785492516274
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 0 pattern 2 with value 0.7736769741665346
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 4 pattern 1 with value 0.7763157894736841
#
# INFEASIBLE PRICING, STOP 0.898
#
# --------------------------------------------------------------------------------
#
# 11 5 apps, DATASET_2/networks/network_030_d_rp_0.dat DATASET_2/apps_merged_FINAL/id_0011.dat
#
# STOP, gap < 0.1 %
# #iterations 31 LR_dual_bound 2330.0750369417715 CG_time 23.458
#
# PureDiving
#
# most selected pattern : app 2 pattern 10 with value 0.8900575458323126
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 9 with value 0.9085705463279419
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 1 pattern 3 with value 0.5748003114276705
#
# INFEASIBLE PRICING, STOP 2.700
#
# --------------------------------------------------------------------------------
#
# 12 6 apps, DATASET_2/networks/network_030_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0012.dat
#
# STOP, gap < 0.1 %
# #iterations 15 LR_dual_bound 2019.7383296787862 CG_time 8.984
#
# PureDiving
#
# most selected pattern : app 2 pattern 3 with value 0.9103467039623548
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 1 pattern 5 with value 0.8200809556011073
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 0 pattern 8 with value 0.8951402631850313
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 3 with value 0.6789127009773778
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 5 pattern 4 with value 0.6630956492981098
#
# INFEASIBLE PRICING, STOP 2.127
#
# --------------------------------------------------------------------------------
#
# 13 6 apps, DATASET_2/networks/network_030_b_rp_2.dat DATASET_2/apps_merged_FINAL/id_0013.dat
#
# STOP, gap < 0.1 %
# #iterations 20 LR_dual_bound 3042.8689242534006 CG_time 12.132
#
# PureDiving
#
# most selected pattern : app 2 pattern 17 with value 0.553444858935309
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 0 pattern 5 with value 0.8236901358997539
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 4 pattern 1 with value 0.6130567964466289
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 2.550
#
# --------------------------------------------------------------------------------
#
# 14 6 apps, DATASET_2/networks/network_030_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0014.dat
#
# STOP, gap < 0.1 %
# #iterations 16 LR_dual_bound 1844.7524396335468 CG_time 3.541
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 13 with value 0.6355639458643002
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 4 pattern 2 with value 0.8626029491542141
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 5 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1927.0 0.758
#
# --------------------------------------------------------------------------------
#
# 15 7 apps, DATASET_2/networks/network_030_d_rp_1.dat DATASET_2/apps_merged_FINAL/id_0015.dat
#
# STOP, gap < 0.1 %
# #iterations 19 LR_dual_bound 2206.187160778566 CG_time 10.843
#
# PureDiving
#
# most selected pattern : app 4 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 6 pattern 5 with value 0.8587341027224762
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 1 with value 0.6271846201388189
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 1 pattern 2 with value 0.5152722537701652
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 5 pattern 4 with value 0.6276612617485691
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 3 pattern 1 with value 0.8255959121076839
#
# INFEASIBLE PRICING, STOP 3.642
#
# --------------------------------------------------------------------------------
#
# 16 7 apps, DATASET_2/networks/network_030_d_rp_1.dat DATASET_2/apps_merged_FINAL/id_0016.dat
#
# STOP, gap < 0.1 %
# #iterations 21 LR_dual_bound 2630.501907320367 CG_time 17.940
#
# PureDiving
#
# most selected pattern : app 6 pattern 2 with value 0.7663551401869159
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 1 with value 0.7470480496139671
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 4.039
#
# --------------------------------------------------------------------------------
#
# 17 7 apps, DATASET_2/networks/network_030_c_rp_3.dat DATASET_2/apps_merged_FINAL/id_0017.dat
#
# STOP, gap < 0.1 %
# #iterations 31 LR_dual_bound 3463.0717765016625 CG_time 14.220
#
# PureDiving
#
# most selected pattern : app 5 pattern 19 with value 0.9319490194107728
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 9.326
#
# --------------------------------------------------------------------------------
#
# 20 8 apps, DATASET_2/networks/network_030_a_rp_1.dat DATASET_2/apps_merged_FINAL/id_0020.dat
#
# STOP, gap < 0.1 %
# #iterations 17 LR_dual_bound 2268.9444632963996 CG_time 7.164
#
# PureDiving
#
# most selected pattern : app 4 pattern 7 with value 0.8767190266253063
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 13 with value 0.6496725927632194
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 6 pattern 13 with value 0.7342087804316606
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 2 with value 0.7715165937261178
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 5 pattern 2 with value 0.8677989090372991
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 1 pattern 4 with value 0.7503367472178388
#
# INFEASIBLE PRICING, STOP 1.767
#
# --------------------------------------------------------------------------------
#
# 87 2 apps, DATASET_2/networks/network_040_a_rp_0.dat DATASET_2/apps_merged_FINAL/id_0087.dat
#
# STOP, gap < 0.1 %
# #iterations 4 LR_dual_bound 805.4532934131737 CG_time 0.622
#
# PureDiving
#
# most selected pattern : app 0 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 819.0 0.068
#
# --------------------------------------------------------------------------------
#
# 88 2 apps, DATASET_2/networks/network_040_c_rp_0.dat DATASET_2/apps_merged_FINAL/id_0088.dat
#
# STOP, gap < 0.1 %
# #iterations 3 LR_dual_bound 753.0660458358102 CG_time 0.554
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 0.990291262135922
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 758.0 0.032
#
# --------------------------------------------------------------------------------
#
# 89 2 apps, DATASET_2/networks/network_040_a_rp_2.dat DATASET_2/apps_merged_FINAL/id_0089.dat
#
# STOP, gap < 0.1 %
# #iterations 3 LR_dual_bound 785.2717424995218 CG_time 1.282
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 0.58290607204405
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 797.0 0.046
#
# --------------------------------------------------------------------------------
#
# 90 3 apps, DATASET_2/networks/network_040_d_rp_1.dat DATASET_2/apps_merged_FINAL/id_0090.dat
#
# STOP, gap < 0.1 %
# #iterations 9 LR_dual_bound 1094.4407228041732 CG_time 1.729
#
# PureDiving
#
# most selected pattern : app 1 pattern 7 with value 0.6232876712328766
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 1 with value 0.7996894409937889
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1161.0 0.416
#
# --------------------------------------------------------------------------------
#
# 91 3 apps, DATASET_2/networks/network_040_b_rp_3.dat DATASET_2/apps_merged_FINAL/id_0091.dat
#
# STOP, gap < 0.1 %
# #iterations 10 LR_dual_bound 1479.1644856782088 CG_time 3.601
#
# PureDiving
#
# most selected pattern : app 1 pattern 8 with value 0.49255914379639204
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 0 pattern 1 with value 0.626547586536297
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1547.0 0.598
#
# --------------------------------------------------------------------------------
#
# 92 3 apps, DATASET_2/networks/network_040_b_rp_1.dat DATASET_2/apps_merged_FINAL/id_0092.dat
#
# STOP, gap < 0.1 %
# #iterations 8 LR_dual_bound 1173.2103989989998 CG_time 3.563
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 0.6202184104231507
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1214.0 0.400
#
# --------------------------------------------------------------------------------
#
# 93 4 apps, DATASET_2/networks/network_040_b_rp_2.dat DATASET_2/apps_merged_FINAL/id_0093.dat
#
# STOP, gap < 0.1 %
# #iterations 31 LR_dual_bound 1429.2973235580414 CG_time 11.997
#
# PureDiving
#
# most selected pattern : app 0 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 1 pattern 7 with value 0.8976888750311488
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 11 with value 0.6121183548879282
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1508.0 0.693
#
# --------------------------------------------------------------------------------
#
# 94 4 apps, DATASET_2/networks/network_040_c_rp_4.dat DATASET_2/apps_merged_FINAL/id_0094.dat
#
# STOP, gap < 0.1 %
# #iterations 9 LR_dual_bound 1387.1685495720628 CG_time 3.839
#
# PureDiving
#
# most selected pattern : app 2 pattern 4 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 6 with value 0.7361590596971908
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 1 pattern 1 with value 0.9091892579865087
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1436.0 0.862
#
# --------------------------------------------------------------------------------
#
# 95 4 apps, DATASET_2/networks/network_040_a_rp_2.dat DATASET_2/apps_merged_FINAL/id_0095.dat
#
# STOP, gap < 0.1 %
# #iterations 17 LR_dual_bound 1649.9588942314433 CG_time 6.534
#
# PureDiving
#
# most selected pattern : app 3 pattern 6 with value 0.6238258113342096
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 2 pattern 1 with value 0.6124672101816644
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1765.0 0.898
#
# --------------------------------------------------------------------------------
#
# 96 5 apps, DATASET_2/networks/network_040_a_rp_0.dat DATASET_2/apps_merged_FINAL/id_0096.dat
#
# STOP, gap < 0.1 %
# #iterations 20 LR_dual_bound 1819.8642462351686 CG_time 6.304
#
# PureDiving
#
# most selected pattern : app 0 pattern 9 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 8 with value 0.5940170940170941
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 4 pattern 1 with value 0.5596832869676867
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1921.0 1.043
#
# --------------------------------------------------------------------------------
#
# 97 5 apps, DATASET_2/networks/network_040_c_rp_3.dat DATASET_2/apps_merged_FINAL/id_0097.dat
#
# STOP, gap < 0.1 %
# #iterations 24 LR_dual_bound 2533.132662079463 CG_time 19.578
#
# PureDiving
#
# most selected pattern : app 3 pattern 1 with value 0.7302182522835151
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 1 pattern 8 with value 0.6076230351942752
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 0 pattern 1 with value 0.6343595146190975
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 4.739
#
# --------------------------------------------------------------------------------
#
# 98 5 apps, DATASET_2/networks/network_040_a_rp_0.dat DATASET_2/apps_merged_FINAL/id_0098.dat
#
# STOP, gap < 0.1 %
# #iterations 25 LR_dual_bound 2669.4298745905653 CG_time 16.364
#
# PureDiving
#
# most selected pattern : app 1 pattern 7 with value 0.7851254433268924
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 0 pattern 3 with value 0.7552727494197056
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 3 pattern 2 with value 0.7286090992368712
#
# STOP, gap < 0.1 % , #iter  9
# most selected pattern : app 2 pattern 4 with value 0.44800460615068777
#
# INFEASIBLE PRICING, STOP 3.540
#
# --------------------------------------------------------------------------------
#
# 99 6 apps, DATASET_2/networks/network_040_c_rp_3.dat DATASET_2/apps_merged_FINAL/id_0099.dat
#
# STOP, gap < 0.1 %
# #iterations 14 LR_dual_bound 2126.9654029387857 CG_time 6.798
#
# PureDiving
#
# most selected pattern : app 3 pattern 10 with value 0.914566492249428
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 3 with value 1.0
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 2 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 1 with value 0.7476125350565469
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2214.0 0.698
#
# --------------------------------------------------------------------------------
#
# 100 6 apps, DATASET_2/networks/network_040_a_rp_1.dat DATASET_2/apps_merged_FINAL/id_0100.dat
#
# STOP, gap < 0.1 %
# #iterations 21 LR_dual_bound 2470.171063182332 CG_time 17.805
#
# PureDiving
#
# most selected pattern : app 2 pattern 7 with value 0.7050656733344653
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 11 with value 0.5209784110682236
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 1 with value 0.874422753923133
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 1 pattern 3 with value 0.7024686591598156
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 4 pattern 1 with value 0.8954703832752614
#
# INFEASIBLE PRICING, STOP 2.401
#
# --------------------------------------------------------------------------------
#
# 101 6 apps, DATASET_2/networks/network_040_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0101.dat
#
# STOP, gap < 0.1 %
# #iterations 20 LR_dual_bound 2489.7534805135633 CG_time 11.923
#
# PureDiving
#
# most selected pattern : app 5 pattern 13 with value 0.6511569580412844
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 1 pattern 7 with value 0.6746110681979857
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 3 pattern 5 with value 0.7742159087827035
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 2 pattern 2 with value 0.7318714654474913
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 4 pattern 2 with value 0.7953996811660213
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2589.0 3.538
#
# --------------------------------------------------------------------------------
#
# 102 7 apps, DATASET_2/networks/network_040_a_rp_2.dat DATASET_2/apps_merged_FINAL/id_0102.dat
# INFEASIBLE INSTANCE : 2-th pricing infeasible with dual values = 0, meaning that you cannot map 2-th application
#
# --------------------------------------------------------------------------------
#
# 104 7 apps, DATASET_2/networks/network_040_a_rp_1.dat DATASET_2/apps_merged_FINAL/id_0104.dat
#
# STOP, gap < 0.1 %
# #iterations 21 LR_dual_bound 2364.438822234855 CG_time 12.214
#
# PureDiving
#
# most selected pattern : app 5 pattern 3 with value 0.6783932071404373
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 6 with value 0.48295058259247076
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 6 pattern 2 with value 0.8294297168161352
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 1 pattern 3 with value 0.6114711593428046
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 0 pattern 1 with value 0.7417648072319567
#
# INFEASIBLE PRICING, STOP 2.004
#
# --------------------------------------------------------------------------------
#
# 105 8 apps, DATASET_2/networks/network_040_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0105.dat
#
# STOP, gap < 0.1 %
# #iterations 24 LR_dual_bound 3415.8566146541734 CG_time 14.968
#
# PureDiving
#
# most selected pattern : app 1 pattern 11 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 15 with value 0.5108701448835261
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 6 pattern 3 with value 0.8953248679675615
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 5 pattern 2 with value 0.738295217574719
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 4 pattern 3 with value 0.6538322816348887
#
# INFEASIBLE PRICING, STOP 2.857
#
# --------------------------------------------------------------------------------
#
# 106 8 apps, DATASET_2/networks/network_040_c_rp_2.dat DATASET_2/apps_merged_FINAL/id_0106.dat
#
# STOP, gap < 0.1 %
# #iterations 19 LR_dual_bound 2751.8063162349827 CG_time 12.773
#
# PureDiving
#
# most selected pattern : app 1 pattern 13 with value 0.8206525069629765
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 0 pattern 7 with value 0.750642140025621
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 6 pattern 1 with value 0.75
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 5 pattern 1 with value 0.7852645977979558
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 2 pattern 1 with value 0.7233641843322087
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 4.232
#
# --------------------------------------------------------------------------------
#
# 107 8 apps, DATASET_2/networks/network_040_a_rp_1.dat DATASET_2/apps_merged_FINAL/id_0107.dat
#
# STOP, gap < 0.1 %
# #iterations 19 LR_dual_bound 2506.331327584507 CG_time 22.261
#
# PureDiving
#
# most selected pattern : app 3 pattern 13 with value 0.6497304325421142
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 4 pattern 1 with value 0.943930680758977
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 1 pattern 3 with value 0.9655674846625766
#
# INFEASIBLE PRICING, STOP 3.391
#
# --------------------------------------------------------------------------------
#
# 108 9 apps, DATASET_2/networks/network_040_c_rp_3.dat DATASET_2/apps_merged_FINAL/id_0108.dat
#
# STOP, gap < 0.1 %
# #iterations 28 LR_dual_bound 3833.445018846976 CG_time 37.130
#
# PureDiving
#
# most selected pattern : app 7 pattern 14 with value 0.7805926331061634
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 6 pattern 6 with value 0.7249882853977906
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 3 pattern 1 with value 0.7374866070711218
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 4 pattern 6 with value 0.639414947797148
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 15.646
#
# --------------------------------------------------------------------------------
#
# 109 9 apps, DATASET_2/networks/network_040_d_rp_4.dat DATASET_2/apps_merged_FINAL/id_0109.dat
#
# STOP, gap < 0.1 %
# #iterations 28 LR_dual_bound 3787.191583685128 CG_time 58.222
#
# PureDiving
#
# most selected pattern : app 2 pattern 16 with value 0.9821452575958424
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 4 pattern 2 with value 0.9497222732718504
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 4 with value 0.6807513625596862
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 1 pattern 3 with value 0.8588635186706349
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 6 pattern 3 with value 0.4952152967656839
#
# STOP, gap < 0.1 % , #iter  11
# most selected pattern : app 5 pattern 7 with value 0.4908245293197977
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 23.569
#
# --------------------------------------------------------------------------------
#
# 110 9 apps, DATASET_2/networks/network_040_b_rp_2.dat DATASET_2/apps_merged_FINAL/id_0110.dat
#
# no new columns found
#
# INFEASIBLE INSTANCE : we are still using a dummy column
# #iterations 51 CG_time 221.653
#
# --------------------------------------------------------------------------------
#
# 111 10 apps, DATASET_2/networks/network_040_a_rp_1.dat DATASET_2/apps_merged_FINAL/id_0111.dat
#
# STOP, gap < 0.1 %
# #iterations 30 LR_dual_bound 3819.7643056432307 CG_time 40.877
#
# PureDiving
#
# most selected pattern : app 1 pattern 8 with value 0.8933783849964396
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 1 with value 0.8005238211587833
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 24.456
#
# --------------------------------------------------------------------------------
#
# 112 10 apps, DATASET_2/networks/network_040_c_rp_3.dat DATASET_2/apps_merged_FINAL/id_0112.dat
#
# STOP, gap < 0.1 %
# #iterations 16 LR_dual_bound 3191.36171354584 CG_time 16.797
#
# PureDiving
#
# most selected pattern : app 9 pattern 10 with value 0.7696291940936538
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 5 pattern 6 with value 0.9076146638669267
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 12.128
#
# --------------------------------------------------------------------------------
#
# 113 10 apps, DATASET_2/networks/network_040_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0113.dat
#
# STOP, gap < 0.1 %
# #iterations 21 LR_dual_bound 3558.393106253555 CG_time 31.174
#
# PureDiving
#
# most selected pattern : app 2 pattern 3 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 16 with value 0.817833886451205
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 7 pattern 2 with value 0.6313966120023724
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 1 pattern 4 with value 0.7260081739375541
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 8 pattern 3 with value 0.6992111478714166
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 5 pattern 2 with value 0.8687559274396571
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 10.052
#
# --------------------------------------------------------------------------------
#
# 115 11 apps, DATASET_2/networks/network_040_a_rp_0.dat DATASET_2/apps_merged_FINAL/id_0115.dat
#
# STOP, gap < 0.1 %
# #iterations 22 LR_dual_bound 3357.978934575384 CG_time 15.859
#
# PureDiving
#
# most selected pattern : app 1 pattern 4 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 10 with value 0.8749516814843415
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 12.885
#
# --------------------------------------------------------------------------------
#
# 117 12 apps, DATASET_2/networks/network_040_b_rp_3.dat DATASET_2/apps_merged_FINAL/id_0117.dat
#
# STOP, gap < 0.1 %
# #iterations 29 LR_dual_bound 4477.13088973835 CG_time 81.789
#
# PureDiving
#
# most selected pattern : app 9 pattern 5 with value 0.9532313885646663
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 11 with value 0.7593863623971838
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 17 with value 0.7147551236151919
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 2 pattern 10 with value 0.7224274718940615
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 43.423
#
# --------------------------------------------------------------------------------
#
# 118 12 apps, DATASET_2/networks/network_040_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0118.dat
#
# STOP, gap < 0.1 %
# #iterations 30 LR_dual_bound 4541.135797338436 CG_time 67.548
#
# PureDiving
#
# most selected pattern : app 0 pattern 5 with value 0.7377124954221773
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 11 pattern 10 with value 0.7709482300028169
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 5 pattern 9 with value 0.6749449633947081
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 3 pattern 15 with value 0.6767409720030515
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 4 pattern 1 with value 0.8196851697707479
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 7 pattern 2 with value 0.7158130408705481
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 36.768
#
# --------------------------------------------------------------------------------
#
# 119 12 apps, DATASET_2/networks/network_040_d_rp_4.dat DATASET_2/apps_merged_FINAL/id_0119.dat
#
# STOP, gap < 0.1 %
# #iterations 18 LR_dual_bound 3637.0042143033397 CG_time 44.313
#
# PureDiving
#
# most selected pattern : app 8 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 10 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 9 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 6 pattern 6 with value 0.7151381588010646
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 1 pattern 1 with value 0.8027836628791187
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 7 pattern 1 with value 0.78652568834664
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 0 pattern 1 with value 0.6897586543061437
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 9 pattern 8 with value 0.7327947202719202
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 11 pattern 3 with value 0.5889474987662955
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 26.262
#
# --------------------------------------------------------------------------------
#
# 120 13 apps, DATASET_2/networks/network_040_a_rp_2.dat DATASET_2/apps_merged_FINAL/id_0120.dat
#
# no new columns found
#
# INFEASIBLE INSTANCE : we are still using a dummy column
# #iterations 38 CG_time 126.800
#
# --------------------------------------------------------------------------------
#
# 122 13 apps, DATASET_2/networks/network_040_b_rp_3.dat DATASET_2/apps_merged_FINAL/id_0122.dat
#
# STOP, gap < 0.1 %
# #iterations 24 LR_dual_bound 4307.78231167934 CG_time 58.151
#
# PureDiving
#
# most selected pattern : app 4 pattern 12 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 12 pattern 20 with value 0.6536737180890771
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 2 with value 0.9289614973951972
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 10 pattern 4 with value 0.6837295132632162
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 2 pattern 6 with value 0.8643794505605935
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 9 pattern 3 with value 0.5547360092602674
#
# STOP, gap < 0.1 % , #iter  8
# most selected pattern : app 0 pattern 11 with value 0.6570602059695503
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 22.417
#
# --------------------------------------------------------------------------------
#
# 174 2 apps, DATASET_2/networks/network_050_a_rp_2.dat DATASET_2/apps_merged_FINAL/id_0174.dat
#
# STOP, gap < 0.1 %
# #iterations 1 LR_dual_bound 667.0 CG_time 0.596
# CG_dà_ottimo_intero 667.0
#
# --------------------------------------------------------------------------------
#
# 175 2 apps, DATASET_2/networks/network_050_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0175.dat
#
# STOP, gap < 0.1 %
# #iterations 1 LR_dual_bound 394.0 CG_time 0.116
# CG_dà_ottimo_intero 394.0
#
# --------------------------------------------------------------------------------
#
# 176 2 apps, DATASET_2/networks/network_050_d_rp_2.dat DATASET_2/apps_merged_FINAL/id_0176.dat
#
# STOP, gap < 0.1 %
# #iterations 2 LR_dual_bound 704.1021505376344 CG_time 0.607
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 707.0 0.066
#
# --------------------------------------------------------------------------------
#
# 177 3 apps, DATASET_2/networks/network_050_d_rp_3.dat DATASET_2/apps_merged_FINAL/id_0177.dat
#
# STOP, gap < 0.1 %
# #iterations 5 LR_dual_bound 727.1496963551717 CG_time 1.365
#
# PureDiving
#
# most selected pattern : app 2 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 1 pattern 2 with value 0.9066360883881808
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 779.0 0.423
#
# --------------------------------------------------------------------------------
#
# 178 3 apps, DATASET_2/networks/network_050_c_rp_4.dat DATASET_2/apps_merged_FINAL/id_0178.dat
#
# STOP, gap < 0.1 %
# #iterations 21 LR_dual_bound 1855.7517958240978 CG_time 14.235
#
# PureDiving
#
# most selected pattern : app 2 pattern 15 with value 0.4242871278853864
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 2 with value 0.6534732282287771
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1918.0 0.832
#
# --------------------------------------------------------------------------------
#
# 179 3 apps, DATASET_2/networks/network_050_c_rp_4.dat DATASET_2/apps_merged_FINAL/id_0179.dat
#
# STOP, gap < 0.1 %
# #iterations 5 LR_dual_bound 1173.5793437804186 CG_time 2.355
#
# PureDiving
#
# most selected pattern : app 0 pattern 1 with value 0.7727431160683166
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1185.0 0.105
#
# --------------------------------------------------------------------------------
#
# 180 4 apps, DATASET_2/networks/network_050_b_rp_3.dat DATASET_2/apps_merged_FINAL/id_0180.dat
#
# STOP, gap < 0.1 %
# #iterations 13 LR_dual_bound 1290.720746046931 CG_time 6.674
#
# PureDiving
#
# most selected pattern : app 0 pattern 5 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 1 with value 0.9823949128033858
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 1 pattern 2 with value 0.7400722021660651
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1327.0 0.991
#
# --------------------------------------------------------------------------------
#
# 181 4 apps, DATASET_2/networks/network_050_d_rp_0.dat DATASET_2/apps_merged_FINAL/id_0181.dat
#
# STOP, gap < 0.1 %
# #iterations 7 LR_dual_bound 1207.9810325306182 CG_time 1.497
#
# PureDiving
#
# most selected pattern : app 2 pattern 2 with value 0.75
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 5 with value 0.585216309569498
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1249.0 0.178
#
# --------------------------------------------------------------------------------
#
# 182 4 apps, DATASET_2/networks/network_050_c_rp_3.dat DATASET_2/apps_merged_FINAL/id_0182.dat
#
# STOP, gap < 0.1 %
# #iterations 6 LR_dual_bound 1295.8151577307826 CG_time 1.947
#
# PureDiving
#
# most selected pattern : app 1 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1308.0 0.307
#
# --------------------------------------------------------------------------------
#
# 183 5 apps, DATASET_2/networks/network_050_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0183.dat
#
# STOP, gap < 0.1 %
# #iterations 3 LR_dual_bound 913.7767287784678 CG_time 1.187
#
# PureDiving
#
# most selected pattern : app 3 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 1 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 4 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 1 with value 0.9361953897855824
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 941.0 0.456
#
# --------------------------------------------------------------------------------
#
# 184 5 apps, DATASET_2/networks/network_050_b_rp_1.dat DATASET_2/apps_merged_FINAL/id_0184.dat
#
# STOP, gap < 0.1 %
# #iterations 17 LR_dual_bound 2135.420109584479 CG_time 13.630
#
# PureDiving
#
# most selected pattern : app 2 pattern 9 with value 0.5986881400255111
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 1 pattern 2 with value 0.5217181670086629
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 4 pattern 1 with value 0.5021928229423508
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 1 with value 0.6580047114090587
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2216.0 2.434
#
# --------------------------------------------------------------------------------
#
# 185 5 apps, DATASET_2/networks/network_050_d_rp_1.dat DATASET_2/apps_merged_FINAL/id_0185.dat
#
# STOP, gap < 0.1 %
# #iterations 11 LR_dual_bound 1836.4468622311708 CG_time 6.556
#
# PureDiving
#
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 3 with value 0.6927336168015379
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 4 pattern 1 with value 0.9441419105183715
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 2 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1896.0 1.719
#
# --------------------------------------------------------------------------------
#
# 186 6 apps, DATASET_2/networks/network_050_b_rp_1.dat DATASET_2/apps_merged_FINAL/id_0186.dat
#
# STOP, gap < 0.1 %
# #iterations 12 LR_dual_bound 1334.6962189104236 CG_time 8.834
#
# PureDiving
#
# most selected pattern : app 4 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 3 with value 0.9131430121312694
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 1 with value 0.6589742736107997
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 4 with value 0.75371710690189
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 5 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 1406.0 2.322
#
# --------------------------------------------------------------------------------
#
# 187 6 apps, DATASET_2/networks/network_050_c_rp_3.dat DATASET_2/apps_merged_FINAL/id_0187.dat
#
# STOP, gap < 0.1 %
# #iterations 16 LR_dual_bound 2381.4360092800434 CG_time 16.099
#
# PureDiving
#
# most selected pattern : app 4 pattern 4 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 6 with value 0.47678175045268156
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 5 pattern 12 with value 0.4934812283168124
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 2 pattern 3 with value 0.7536398019819889
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 1 pattern 1 with value 0.6114191419141919
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2572.0 5.304
#
# --------------------------------------------------------------------------------
#
# 188 6 apps, DATASET_2/networks/network_050_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0188.dat
#
# STOP, gap < 0.1 %
# #iterations 26 LR_dual_bound 2718.726041895125 CG_time 26.148
#
# PureDiving
#
# most selected pattern : app 2 pattern 19 with value 0.47525769758650205
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 4 pattern 4 with value 0.5961930862187421
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 5 pattern 1 with value 0.8712736545497002
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 2 with value 0.6925349133514236
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 1 with value 0.8873489694385216
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2838.0 4.760
#
# --------------------------------------------------------------------------------
#
# 189 7 apps, DATASET_2/networks/network_050_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0189.dat
#
# STOP, gap < 0.1 %
# #iterations 18 LR_dual_bound 2394.9902403966175 CG_time 22.450
#
# PureDiving
#
# most selected pattern : app 0 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 11 with value 0.6965316342872989
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 4 pattern 8 with value 0.7354445416723621
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 1 with value 0.6075418994413408
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 6 pattern 1 with value 0.885486981677917
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 1 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2509.0 5.323
#
# --------------------------------------------------------------------------------
#
# 190 7 apps, DATASET_2/networks/network_050_b_rp_0.dat DATASET_2/apps_merged_FINAL/id_0190.dat
#
# STOP, gap < 0.1 %
# #iterations 14 LR_dual_bound 2268.3185074447324 CG_time 12.940
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 4 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 9 with value 0.6671456072095762
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 2 pattern 2 with value 0.8924865089248651
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 6 pattern 1 with value 0.9213199243653888
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2323.0 3.883
#
# --------------------------------------------------------------------------------
#
# 191 7 apps, DATASET_2/networks/network_050_b_rp_0.dat DATASET_2/apps_merged_FINAL/id_0191.dat
#
# STOP, gap < 0.1 %
# #iterations 17 LR_dual_bound 2595.53294908218 CG_time 25.001
#
# PureDiving
#
# most selected pattern : app 2 pattern 10 with value 0.7287273747016575
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 2 with value 0.6348479429425188
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 4 pattern 3 with value 0.9174379735699781
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 1 with value 0.7752671320573161
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 5 pattern 1 with value 0.6753116874458297
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2723.0 6.392
#
# --------------------------------------------------------------------------------
#
# 192 8 apps, DATASET_2/networks/network_050_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0192.dat
#
# STOP, gap < 0.1 %
# #iterations 16 LR_dual_bound 2240.453139166055 CG_time 18.939
#
# PureDiving
#
# most selected pattern : app 1 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 4 pattern 15 with value 0.6805175935431336
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 6 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 3 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 2 pattern 1 with value 0.879154078549849
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2396.0 3.760
#
# --------------------------------------------------------------------------------
#
# 193 8 apps, DATASET_2/networks/network_050_d_rp_2.dat DATASET_2/apps_merged_FINAL/id_0193.dat
#
# STOP, gap < 0.1 %
# #iterations 10 LR_dual_bound 2224.560855705719 CG_time 6.379
#
# PureDiving
#
# most selected pattern : app 0 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 6 pattern 4 with value 0.7130434782608696
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 1 with value 0.71324828730046
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 2 pattern 3 with value 0.7598380822433966
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 1 pattern 1 with value 0.8412831957794172
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 4 pattern 1 with value 0.6900584795321638
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2318.0 4.416
#
# --------------------------------------------------------------------------------
#
# 194 8 apps, DATASET_2/networks/network_050_a_rp_3.dat DATASET_2/apps_merged_FINAL/id_0194.dat
#
# STOP, gap < 0.1 %
# #iterations 12 LR_dual_bound 2134.180405910369 CG_time 9.338
#
# PureDiving
#
# most selected pattern : app 3 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 1 pattern 4 with value 0.7643258627811351
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 1 with value 0.8480860023111086
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 2 pattern 3 with value 0.6266561745113828
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 6 pattern 1 with value 0.8012095914840518
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 2232.0 4.311
#
# --------------------------------------------------------------------------------
#
# 195 9 apps, DATASET_2/networks/network_050_a_rp_3.dat DATASET_2/apps_merged_FINAL/id_0195.dat
#
# STOP, gap < 0.1 %
# #iterations 20 LR_dual_bound 3783.732930151362 CG_time 35.454
#
# PureDiving
#
# most selected pattern : app 4 pattern 19 with value 0.8585204394401861
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 9 with value 0.6592159734049482
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 2 pattern 4 with value 0.9130565712025973
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 7 pattern 6 with value 0.7527797732947145
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 8 pattern 1 with value 0.6473680384552949
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 6 pattern 1 with value 0.9061799660271259
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 1 pattern 2 with value 0.8821280793328504
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 1 with value 0.9213414634146342
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 3987.0 8.765
#
# --------------------------------------------------------------------------------
#
# 196 9 apps, DATASET_2/networks/network_050_a_rp_2.dat DATASET_2/apps_merged_FINAL/id_0196.dat
#
# STOP, gap < 0.1 %
# #iterations 16 LR_dual_bound 2576.785541771252 CG_time 12.451
#
# PureDiving
#
# ...
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 10 pattern 1 with value 0.6123560637386651
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 1 pattern 3 with value 0.6246122224235989
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 77.782
#
# --------------------------------------------------------------------------------
#
# 479 16 apps, DATASET_2/networks/network_080_b_rp_2.dat DATASET_2/apps_merged_FINAL/id_0479.dat
#
# STOP, gap < 0.1 %
# #iterations 27 LR_dual_bound 5252.51326738877 CG_time 167.372
#
# PureDiving
#
# most selected pattern : app 6 pattern 2 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 11 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 12 pattern 15 with value 0.8863447364115112
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 4 pattern 10 with value 0.8270005463706375
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 9 with value 0.8419194499768238
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 14 pattern 6 with value 0.6971280869883202
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 9 pattern 6 with value 0.7339759262561886
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 2 with value 0.9255845722841665
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 8 pattern 14 with value 0.9309868930421275
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 13 pattern 3 with value 0.8429666607821922
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 11 pattern 3 with value 0.6233984524747566
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 1 pattern 2 with value 0.958676481750774
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 2 pattern 12 with value 0.5880808482882284
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 10 pattern 3 with value 0.9111941276244863
#
# INFEASIBLE PRICING, STOP 61.051
#
# --------------------------------------------------------------------------------
#
# 480 17 apps, DATASET_2/networks/network_080_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0480.dat
#
# STOP, gap < 0.1 %
# #iterations 27 LR_dual_bound 6240.939194587361 CG_time 292.667
#
# PureDiving
#
# most selected pattern : app 2 pattern 11 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 9 pattern 4 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 12 pattern 2 with value 0.6555622759851556
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 15 pattern 16 with value 0.7446596159839888
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 3 pattern 4 with value 0.7561819288906859
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 11 pattern 4 with value 0.8275431042738008
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 4 pattern 1 with value 0.6817828990856247
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 13 pattern 3 with value 0.7163890233319913
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 7 pattern 10 with value 0.6380566571201491
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 8 pattern 1 with value 0.7221273298162582
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 0 pattern 4 with value 0.5654736354814263
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 6 pattern 1 with value 0.7932911946124626
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 10 pattern 5 with value 0.6256651650318154
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 1 pattern 6 with value 0.8658068561825625
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 3 with value 0.7579052891355258
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 16 pattern 1 with value 0.523955480850835
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 6829.0 101.835
#
# --------------------------------------------------------------------------------
#
# 481 17 apps, DATASET_2/networks/network_080_b_rp_2.dat DATASET_2/apps_merged_FINAL/id_0481.dat
#
# STOP, gap < 0.1 %
# #iterations 28 LR_dual_bound 6093.535435242782 CG_time 231.526
#
# PureDiving
#
# most selected pattern : app 2 pattern 11 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 11 pattern 11 with value 0.9757742988482276
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 13 pattern 11 with value 0.8917016401590491
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 14 pattern 21 with value 0.6908570146695538
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 1 with value 0.7373484240554726
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 8 pattern 18 with value 0.6057142857142858
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 4 pattern 1 with value 0.9759050728721775
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 1 pattern 5 with value 0.9839319159324261
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 15 pattern 1 with value 0.6508533170960858
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 16 pattern 2 with value 0.7920399222780983
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 6 pattern 1 with value 0.9699194227162081
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 9 pattern 2 with value 0.532881540887888
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 3 pattern 1 with value 0.7563821582138007
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 5 pattern 1 with value 0.9060748098545903
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 5 with value 1.0
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 10 pattern 1 with value 0.41139551349605924
#
# STOP, gap < 0.1 % , #iter  2
# CG_dà_già_ottimo_intero
# DIVING_SUCCESS primal_bound 6523.0 88.069
#
# --------------------------------------------------------------------------------
#
# 482 17 apps, DATASET_2/networks/network_080_a_rp_0.dat DATASET_2/apps_merged_FINAL/id_0482.dat
#
# STOP, gap < 0.1 %
# #iterations 33 LR_dual_bound 7134.749784843799 CG_time 306.846
#
# PureDiving
#
# most selected pattern : app 4 pattern 5 with value 0.784195377473497
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 8 pattern 21 with value 0.9100517882077106
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 13 pattern 25 with value 0.7253931055627172
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 6 pattern 7 with value 0.9934476159986421
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 15 pattern 5 with value 0.6938176787712498
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 10 pattern 8 with value 0.6023638201245737
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 2 pattern 4 with value 0.6891157027296028
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 12 pattern 3 with value 0.8000304031653109
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 9 pattern 2 with value 0.6814286536435256
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 0 pattern 7 with value 0.8055438321874474
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 7 pattern 1 with value 0.8435533292390596
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 16 pattern 1 with value 0.6107026170198947
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 14 pattern 4 with value 0.6445246338502618
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 3 pattern 1 with value 1.0
#
# INFEASIBLE PRICING, STOP 87.672
#
# --------------------------------------------------------------------------------
#
# 483 18 apps, DATASET_2/networks/network_080_b_rp_0.dat DATASET_2/apps_merged_FINAL/id_0483.dat
#
# STOP, gap < 0.1 %
# #iterations 40 LR_dual_bound 7787.453561659827 CG_time 519.790
#
# PureDiving
#
# most selected pattern : app 4 pattern 6 with value 0.7036458140204525
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 12 pattern 21 with value 0.8645612022313439
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 8 pattern 13 with value 0.6142849655723999
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 15 pattern 8 with value 0.8448152156326912
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 17 pattern 5 with value 0.892429847320221
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 11 pattern 10 with value 0.700260523963359
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 14 pattern 6 with value 0.49264551291483083
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 6 pattern 3 with value 0.6763398275611132
#
# STOP, gap < 0.1 % , #iter  5
# most selected pattern : app 9 pattern 2 with value 0.5757496832509222
#
# STOP, gap < 0.1 % , #iter  11
# most selected pattern : app 16 pattern 2 with value 0.7515820455998568
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 267.505
#
# --------------------------------------------------------------------------------
#
# 484 18 apps, DATASET_2/networks/network_080_d_rp_0.dat DATASET_2/apps_merged_FINAL/id_0484.dat
#
# STOP, gap < 0.1 %
# #iterations 32 LR_dual_bound 6675.505986367995 CG_time 227.779
#
# PureDiving
#
# most selected pattern : app 11 pattern 15 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 13 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 15 pattern 4 with value 0.7893732291945487
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 16 with value 0.8186047070408767
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 4 pattern 15 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 10 pattern 6 with value 0.8244802125190641
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 2 pattern 1 with value 0.7664210946159734
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 14 pattern 1 with value 0.7953249705086557
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 9 pattern 8 with value 0.7709272771896772
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 0 pattern 1 with value 0.8410273604183659
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 8 pattern 1 with value 0.8016895030577158
#
# STOP, gap < 0.1 % , #iter  6
# most selected pattern : app 1 pattern 7 with value 0.7639937025387128
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 79.366
#
# --------------------------------------------------------------------------------
#
# 485 18 apps, DATASET_2/networks/network_080_d_rp_3.dat DATASET_2/apps_merged_FINAL/id_0485.dat
#
# STOP, gap < 0.1 %
# #iterations 33 LR_dual_bound 7870.59623045608 CG_time 242.639
#
# PureDiving
#
# most selected pattern : app 8 pattern 23 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 12 pattern 1 with value 1.0
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 7 pattern 11 with value 0.7974695688795985
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 15 pattern 12 with value 0.6778133030171168
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 5 pattern 15 with value 0.6967233319643142
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 0 pattern 9 with value 0.9691969275675263
#
# STOP, gap < 0.1 % , #iter  1
# most selected pattern : app 17 pattern 12 with value 0.628186948285804
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 2 pattern 5 with value 0.6330916393947894
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 3 pattern 1 with value 0.6758973074105936
#
# STOP, gap < 0.1 % , #iter  2
# most selected pattern : app 16 pattern 17 with value 0.6653487587275642
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 9 pattern 4 with value 0.5429109214793897
#
# STOP, gap < 0.1 % , #iter  4
# most selected pattern : app 13 pattern 4 with value 0.7654556387442008
#
# STOP, gap < 0.1 % , #iter  8
# most selected pattern : app 4 pattern 6 with value 0.6210192390195592
#
# STOP, gap < 0.1 % , #iter  3
# most selected pattern : app 14 pattern 1 with value 0.6523075704839555
#
# no new columns found
#
# INFEASIBLE still dummy, STOP 99.333
#
# --------------------------------------------------------------------------------
#
# 486 19 apps, DATASET_2/networks/network_080_a_rp_2.dat DATASET_2/apps_merged_FINAL/id_0486.dat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
#      26     cg = ColumnGeneration(
#      27         N= len(app_filenames),
#      28         filenames= (
#    (...)
#      32         logger= logger
#      33     )
#      34     # result = cg.execute()
# ---> 35     cg.execute()
#      36 except Exception as e:
#      37     print(f"ERROR in ColumnGeneration : {e}")
#
# File ~/Desktop/tesi_nuove_strutture/tesi-magistrale/O3_NEW_solver/FINAL_src_CG_basic_PureDiving_new.py:1429, in ColumnGeneration.execute(self)
#    1422 new_columns_found = False
#    1424 for n in range(N):
#    1425
#    1426     #print('\033' + f"... solving pricing of {n}-th application\t\t" + '\033', end='')
#    1427
#    1428     # non deve essere infeasible
# -> 1429     new_column, x, reduced_cost = pricings[n].optimize(λ_positive, μ_positive, η[n])
#    1431     if reduced_cost >= -EPSILON:
#    1432         #print("--> NOT added to master")
#    1433         pass
#
# File ~/Desktop/tesi_nuove_strutture/tesi-magistrale/O3_NEW_solver/FINAL_src_CG_basic_PureDiving_new.py:792, in Pricing.optimize(self, λ_positive, μ_positive, η_n)
#     775 (
#     776     I,A,c,P,a2,
#     777     T,D,
#    (...)
#     780     b_microservices_zero, b_connections_zero_not_implied, b_connections_one_actual
#     781 ) = self.data
#     783 #start = perf_counter()
#     784 model.setObjective(
#     785     gp.quicksum(c[i] * x[u,i] for u in range(T) for i in range(I))
#     786     - η_n
#     787     + gp.quicksum(
#     788         q_microservices_R_core[u] * λ_value * x[u,i]
#     789             for (i, λ_value) in λ_positive
#     790                 for u in range(T)
#     791     )
# --> 792     + gp.quicksum(
#     793         q_connections_R_bandwidth[u,v] * μ_value * x[u,i] * x[v,j]
#     794             for ((l,m), μ_value) in μ_positive
#     795                 for (i,j) in a2[l][m]
#     796                     for (u,v) in D
#     797     ),
#     798     GRB.MINIMIZE
#     799 )
#     800 #end = perf_counter()
#     801 #obj_build_time = end-start
#     803 model.optimize()
#
# File src/gurobipy/gurobi.pxi:3842, in gurobipy.quicksum()
#
# File ~/Desktop/tesi_nuove_strutture/tesi-magistrale/O3_NEW_solver/FINAL_src_CG_basic_PureDiving_new.py:793, in <genexpr>(.0)
#     775 (
#     776     I,A,c,P,a2,
#     777     T,D,
#    (...)
#     780     b_microservices_zero, b_connections_zero_not_implied, b_connections_one_actual
#     781 ) = self.data
#     783 #start = perf_counter()
#     784 model.setObjective(
#     785     gp.quicksum(c[i] * x[u,i] for u in range(T) for i in range(I))
#     786     - η_n
#     787     + gp.quicksum(
#     788         q_microservices_R_core[u] * λ_value * x[u,i]
#     789             for (i, λ_value) in λ_positive
#     790                 for u in range(T)
#     791     )
#     792     + gp.quicksum(
# --> 793         q_connections_R_bandwidth[u,v] * μ_value * x[u,i] * x[v,j]
#     794             for ((l,m), μ_value) in μ_positive
#     795                 for (i,j) in a2[l][m]
#     796                     for (u,v) in D
#     797     ),
#     798     GRB.MINIMIZE
#     799 )
#     800 #end = perf_counter()
#     801 #obj_build_time = end-start
#     803 model.optimize()
#
# File src/gurobipy/linexpr.pxi:536, in gurobipy.LinExpr.__mul__()
#
# File src/gurobipy/quadexpr.pxi:45, in gurobipy.QuadExpr.__init__()
#
# File src/gurobipy/linexpr.pxi:48, in gurobipy.LinExpr.__init__()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:
