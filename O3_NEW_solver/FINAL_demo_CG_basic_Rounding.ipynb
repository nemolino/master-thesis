# %%
import logging
import pickle
import numpy as np

# %%
from instance import Instance, InfeasibleOnBuilding
from FINAL_src_CG_basic_Rounding import ColumnGeneration

# %%
def setup_logger(name, log_file, level):

    formatter = logging.Formatter('%(levelname)s %(message)s')
    handler = logging.FileHandler(log_file, mode='w')        
    handler.setFormatter(formatter)

    logger = logging.getLogger(name)
    logger.setLevel(level)
    logger.addHandler(handler)

    return logger

# %%
with open('instances_dataset_FINAL.pickle', 'rb') as f:
   instances = pickle.load(f)

with open('needed_primal_indexes.pickle', 'rb') as f:
   indexes = pickle.load(f)

# %%
for network_size in indexes:
        
    for idx in indexes[network_size]:

        i = instances[idx]

        network_filename, network_rp_filename, app_merged, app_merged_rp, app_filenames, app_rp_filenames = i
        print(f"{idx} {len(app_filenames)} apps, {network_rp_filename} {app_merged}")
        

        # try:
        #     instance = Instance.build(
        #         network_filename, 
        #         network_rp_filename, 
        #         app_merged, 
        #         app_merged_rp
        #     )
        # except InfeasibleOnBuilding:
        #     print("INFEASIBLE on building")
        #     continue

        
        logger = setup_logger(f"logger_{idx:03d}", f"logs/id_{idx:04d}.log", logging.DEBUG)
        
        try:
            cg = ColumnGeneration(
                N= len(app_filenames),
                filenames= (
                    network_filename, network_rp_filename, 
                    app_filenames, app_rp_filenames,
                    app_merged, app_merged_rp
                ),
                logger= logger
            )
            # result = cg.execute()
            cg.execute()
        except Exception as e:
            print(f"ERROR in ColumnGeneration : {e}")
            raise RuntimeError()
        
        
        # print()
        # print(f"dual {result[0]} primal {result[1]}")

        # CG_DUAL_BOUND[idx] = result[0]
        # CG_PRIMAL_BOUND[idx] = result[1]
        # CG_TIME[idx] = result[2]
    
        print("\n" + "-" * 80 + "\n")
# Out:
# 0 2 apps, DATASET_2/networks/network_030_a_rp_0.dat DATASET_2/apps_merged_FINAL/id_0000.dat
#
# STOP, gap < 0.1 %
# #iterations 3 LR_dual_bound 410.27598322566024 CG_time 2.793
#
# application 0
# 	pattern    1 : 0.833 [29, 15, 6, 17, 6, 1]
# 	pattern    3 : 0.167 [29, 3, 6, 0, 0, 0]
# application 1
# 	pattern    1 : 0.679 [29, 0, 0, 29]
# 	pattern    2 : 0.321 [29, 17, 1, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  0 2 6 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 0 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 15 0.8329744229098189
# removed_columns_count 2
# GAP # iterations : 3 master obj val : 413.1314615599988
# n_most,u_most,i_most,z_most =  0 3 17 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 4 6 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 413.1314615599988
# ... solving restricted compact model
# new solution found: z = 429.0 , time = 0.14491291699982867
# 0.146 result (0.0015339851379394531, 'OPTIMAL', 0.0, 429.0, None)
#
# --------------------------------------------------------------------------------
#
# 1 2 apps, DATASET_2/networks/network_030_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0001.dat
#
# STOP, gap < 0.1 %
# #iterations 6 LR_dual_bound 570.2159775190687 CG_time 0.181
#
# application 0
# 	pattern    2 : 0.259 [29, 1, 1]
# 	pattern    5 : 0.213 [29, 6, 1]
# 	pattern    6 : 0.528 [29, 1, 17]
# application 1
# 	pattern    5 : 1.000 [29, 29, 17, 1, 10, 6, 6, 29, 1, 7, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  1 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 2 17 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 570.2159775190687
# n_most,u_most,i_most,z_most =  1 3 1 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 4 10 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 5 6 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 570.2159775190687
# n_most,u_most,i_most,z_most =  1 6 6 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 7 29 1.0
# removed_columns_count 0
# ... solving restricted compact model
# new solution found: z = 573.0 , time = 0.04883791700012807
# 0.050 result (0.001611948013305664, 'OPTIMAL', 1.0, 573.0, None)
#
# --------------------------------------------------------------------------------
#
# 2 2 apps, DATASET_2/networks/network_030_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0002.dat
#
# STOP, gap < 0.1 %
# #iterations 8 LR_dual_bound 940.6254739034483 CG_time 0.635
#
# application 0
# 	pattern    1 : 0.180 [29, 1, 1, 3, 17, 29, 6, 6, 13, 15, 29, 29, 29]
# 	pattern    2 : 0.400 [29, 1, 1, 13, 10, 29, 17, 17, 3, 15, 29, 29, 29]
# 	pattern    7 : 0.315 [29, 1, 1, 3, 10, 29, 5, 6, 13, 15, 29, 29, 29]
# 	pattern    8 : 0.105 [29, 1, 1, 3, 17, 29, 5, 6, 13, 15, 29, 29, 29]
# application 1
# 	pattern    1 : 0.578 [29, 10, 29, 29, 6, 29, 17, 6, 1, 6]
# 	pattern    8 : 0.422 [29, 7, 29, 29, 6, 29, 17, 6, 1, 6]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  0 0 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 1 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 4 6 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 940.6696555875466
# n_most,u_most,i_most,z_most =  0 2 1 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 940.6696555875466
# n_most,u_most,i_most,z_most =  0 5 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 5 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 9 15 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 940.6696555875466
# n_most,u_most,i_most,z_most =  1 6 17 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 940.6696555875466
# n_most,u_most,i_most,z_most =  1 7 6 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 940.6696555875466
# n_most,u_most,i_most,z_most =  1 8 1 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 9 6 1.0
# removed_columns_count 0
# ... solving restricted compact model
# new solution found: z = 989.0 , time = 0.2644779589998052
# new solution found: z = 973.0 , time = 0.2647954589999699
# new solution found: z = 966.0 , time = 0.26511170899993886
# 0.267 result (0.0058019161224365234, 'OPTIMAL', 1.0, 966.0, None)
#
# --------------------------------------------------------------------------------
#
# 3 3 apps, DATASET_2/networks/network_030_c_rp_0.dat DATASET_2/apps_merged_FINAL/id_0003.dat
#
# STOP, gap < 0.1 %
# #iterations 6 LR_dual_bound 695.2447040450787 CG_time 0.597
#
# application 0
# 	pattern    1 : 0.389 [29, 6, 2, 2, 6]
# 	pattern    5 : 0.611 [29, 14, 6, 2, 2]
# application 1
# 	pattern    5 : 1.000 [29, 2, 10, 29, 12]
# application 2
# 	pattern    1 : 0.207 [29, 29, 6, 29, 29, 2, 29, 2]
# 	pattern    2 : 0.184 [29, 29, 12, 29, 29, 10, 29, 6]
# 	pattern    5 : 0.255 [29, 29, 12, 29, 29, 2, 29, 12]
# 	pattern    6 : 0.353 [29, 29, 12, 29, 29, 10, 29, 2]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  1 1 2 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 695.643943588805
# n_most,u_most,i_most,z_most =  2 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 2 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 695.643943588805
# n_most,u_most,i_most,z_most =  1 2 10 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 4 12 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 695.643943588805
# n_most,u_most,i_most,z_most =  2 2 12 0.7931438435269937
# removed_columns_count 2
# GAP # iterations : 2 master obj val : 695.4982880748128
# ... solving restricted compact model
# new solution found: z = 707.0 , time = 0.2655353750001268
# 0.267 result (0.002290964126586914, 'OPTIMAL', 0.0, 707.0, None)
#
# --------------------------------------------------------------------------------
#
# 4 3 apps, DATASET_2/networks/network_030_a_rp_3.dat DATASET_2/apps_merged_FINAL/id_0004.dat
#
# STOP, gap < 0.1 %
# #iterations 3 LR_dual_bound 804.392432864131 CG_time 0.266
#
# application 0
# 	pattern    2 : 1.000 [29, 29, 6, 13, 7, 0, 29, 29]
# application 1
# 	pattern    1 : 0.503 [29, 9, 17]
# 	pattern    2 : 0.133 [29, 14, 17]
# 	pattern    3 : 0.365 [29, 8, 17]
# application 2
# 	pattern    1 : 1.000 [29, 8, 29, 1, 29, 9, 17, 29, 17]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  0 0 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 1 8 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 804.392432864131
# n_most,u_most,i_most,z_most =  1 2 17 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 2 6 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 804.392432864131
# n_most,u_most,i_most,z_most =  2 3 1 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 13 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 4 7 1.0
# removed_columns_count 0
# ... solving restricted compact model
# new solution found: z = 865.0 , time = 0.13445287500007908
# new solution found: z = 808.0 , time = 0.1349067080000168
# 0.137 result (0.005249977111816406, 'OPTIMAL', 1.0, 808.0, None)
#
# --------------------------------------------------------------------------------
#
# 5 3 apps, DATASET_2/networks/network_030_c_rp_4.dat DATASET_2/apps_merged_FINAL/id_0005.dat
#
# STOP, gap < 0.1 %
# #iterations 8 LR_dual_bound 957.993672909767 CG_time 1.733
#
# application 0
# 	pattern    5 : 0.169 [29, 10, 16, 6, 2, 29, 6, 5]
# 	pattern    6 : 0.117 [29, 12, 6, 6, 10, 29, 2, 5]
# 	pattern    7 : 0.714 [29, 10, 16, 6, 2, 29, 6, 6]
# application 1
# 	pattern    1 : 0.854 [29, 29, 10, 29]
# 	pattern    3 : 0.146 [29, 29, 12, 29]
# application 2
# 	pattern    3 : 0.567 [29, 29, 12, 29, 15, 29, 29, 12, 2, 29, 29, 29, 29, 0, 29]
# 	pattern    5 : 0.127 [29, 29, 12, 29, 15, 29, 29, 10, 10, 29, 29, 29, 29, 0, 29]
# 	pattern    6 : 0.106 [29, 29, 12, 29, 15, 29, 29, 6, 2, 29, 29, 29, 29, 0, 29]
# 	pattern    8 : 0.201 [29, 29, 12, 29, 15, 29, 29, 12, 2, 29, 29, 29, 29, 6, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  1 0 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 2 12 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 958.0289514243557
# n_most,u_most,i_most,z_most =  0 3 6 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 958.0289514243557
# n_most,u_most,i_most,z_most =  2 3 29 0.9999999999999993
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 4 15 0.9999999999999993
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 5 29 0.9999999999999993
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 6 29 0.9999999999999993
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 9 29 0.9999999999999993
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 11 29 0.9999999999999993
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 12 29 0.9999999999999993
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 10 0.8825071035165396
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 958.6436778783793
# ... solving restricted compact model
# new solution found: z = 1008.0 , time = 0.4139686660000734
# new solution found: z = 982.0 , time = 0.4151187499999196
# 0.418 result (0.010181903839111328, 'OPTIMAL', 1.0, 982.0, None)
#
# --------------------------------------------------------------------------------
#
# 6 4 apps, DATASET_2/networks/network_030_a_rp_1.dat DATASET_2/apps_merged_FINAL/id_0006.dat
#
# STOP, gap < 0.1 %
# #iterations 12 LR_dual_bound 1373.4126999511518 CG_time 3.088
#
# application 0
# 	pattern    3 : 0.240 [29, 14, 29, 11, 9, 0, 29, 8, 1]
# 	pattern    8 : 0.219 [29, 14, 29, 11, 17, 0, 29, 14, 17]
# 	pattern    9 : 0.090 [29, 14, 29, 11, 17, 1, 29, 14, 17]
# 	pattern   10 : 0.099 [29, 7, 29, 5, 15, 1, 29, 15, 10]
# 	pattern   11 : 0.352 [29, 5, 29, 11, 17, 0, 29, 15, 14]
# application 1
# 	pattern    1 : 0.098 [29, 29, 6, 29, 6, 17, 29, 29]
# 	pattern    5 : 0.885 [29, 29, 6, 29, 6, 14, 29, 29]
# 	pattern    7 : 0.017 [29, 29, 6, 29, 6, 4, 29, 29]
# application 2
# 	pattern    5 : 0.746 [29, 29, 4, 6, 17, 1]
# 	pattern    7 : 0.254 [29, 29, 4, 6, 6, 6]
# application 3
# 	pattern    6 : 0.026 [29, 29, 10, 29, 29, 14, 29, 0, 17, 29, 29, 6, 5]
# 	pattern    9 : 0.141 [29, 29, 10, 29, 29, 15, 29, 1, 0, 29, 29, 6, 5]
# 	pattern   11 : 0.446 [29, 29, 10, 29, 29, 15, 29, 1, 17, 29, 29, 0, 5]
# 	pattern   12 : 0.386 [29, 29, 10, 29, 29, 15, 29, 1, 17, 29, 29, 6, 5]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  1 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 2 6 1.0
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 1373.4126999511518
# n_most,u_most,i_most,z_most =  0 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 2 10 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1373.4126999511518
# n_most,u_most,i_most,z_most =  1 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 4 6 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 2 4 1.0
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 1373.4126999511518
# n_most,u_most,i_most,z_most =  1 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 4 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 3 6 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1373.4126999511518
# n_most,u_most,i_most,z_most =  3 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 7 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 10 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 12 5 1.0
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 1373.4126999511518
# n_most,u_most,i_most,z_most =  3 5 15 0.9735081950699216
# removed_columns_count 2
# GAP # iterations : 2 master obj val : 1373.4261959154292
# n_most,u_most,i_most,z_most =  3 7 1 0.9935689240073945
# removed_columns_count 2
# GAP # iterations : 2 master obj val : 1373.4638584400382
# n_most,u_most,i_most,z_most =  1 5 14 0.8941824427636387
# removed_columns_count 2
# GAP # iterations : 4 master obj val : 1375.2795913664875
# ... solving restricted compact model
# new solution found: z = 1517.0 , time = 3.101492083000039
# new solution found: z = 1486.0 , time = 3.1021690410000247
# new solution found: z = 1420.0 , time = 3.1051809579998917
# 3.107 result (0.032943010330200195, 'OPTIMAL', 1.0, 1420.0, None)
#
# --------------------------------------------------------------------------------
#
# 7 4 apps, DATASET_2/networks/network_030_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0007.dat
#
# STOP, gap < 0.1 %
# #iterations 8 LR_dual_bound 1084.5926812886041 CG_time 0.895
#
# application 0
# 	pattern    1 : 1.000 [29, 10, 8, 8, 8]
# application 1
# 	pattern    2 : 0.140 [29, 29, 4, 29, 29, 29, 0, 10, 19, 16, 29, 29, 11]
# 	pattern    6 : 0.415 [29, 29, 0, 29, 29, 29, 4, 10, 5, 16, 29, 29, 19]
# 	pattern    7 : 0.359 [29, 29, 0, 29, 29, 29, 4, 19, 5, 16, 29, 29, 11]
# 	pattern    8 : 0.086 [29, 29, 0, 29, 29, 29, 4, 10, 5, 16, 29, 29, 11]
# application 2
# 	pattern    2 : 0.718 [29, 19, 9, 29, 16, 29, 11, 29]
# 	pattern    6 : 0.266 [29, 11, 9, 29, 8, 29, 8, 29]
# 	pattern    7 : 0.016 [29, 19, 9, 29, 8, 29, 11, 29]
# application 3
# 	pattern    1 : 1.000 [29, 29, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  3 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 2 9 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1084.5926812886041
# n_most,u_most,i_most,z_most =  1 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 10 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 1084.5926812886041
# n_most,u_most,i_most,z_most =  1 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 9 16 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1084.5926812886041
# n_most,u_most,i_most,z_most =  1 10 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 11 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 7 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 2 8 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 8 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 4 8 1.0
# removed_columns_count 0
# ... solving restricted compact model
# new solution found: z = 1142.0 , time = 0.3156457089999094
# new solution found: z = 1116.0 , time = 0.31617420899988247
# 0.318 result (0.0043909549713134766, 'OPTIMAL', 1.0, 1116.0, None)
#
# --------------------------------------------------------------------------------
#
# 8 4 apps, DATASET_2/networks/network_030_d_rp_2.dat DATASET_2/apps_merged_FINAL/id_0008.dat
#
# STOP, gap < 0.1 %
# #iterations 14 LR_dual_bound 1645.137137862996 CG_time 4.393
#
# application 0
# 	pattern    7 : 0.792 [6, 6, 29, 1, 4, 29, 3, 29, 29, 29, 29, 29]
# 	pattern   11 : 0.047 [6, 6, 29, 1, 4, 29, 9, 29, 29, 29, 29, 29]
# 	pattern   12 : 0.162 [6, 6, 29, 1, 4, 29, 11, 29, 29, 29, 29, 29]
# application 1
# 	pattern    2 : 0.050 [29, 11, 29, 29, 6, 2, 2, 14, 17, 29]
# 	pattern    3 : 0.040 [29, 9, 29, 29, 17, 2, 2, 3, 4, 29]
# 	pattern    4 : 0.292 [29, 4, 29, 29, 4, 2, 2, 3, 4, 29]
# 	pattern    9 : 0.023 [29, 4, 29, 29, 15, 2, 2, 14, 15, 29]
# 	pattern   10 : 0.527 [29, 9, 29, 29, 15, 2, 2, 3, 4, 29]
# 	pattern   14 : 0.069 [29, 11, 29, 29, 6, 2, 2, 3, 4, 29]
# application 2
# 	pattern    4 : 0.071 [29, 29, 4, 11, 4, 29, 9, 4, 2, 29, 4, 4, 29]
# 	pattern    8 : 0.446 [29, 29, 15, 11, 17, 29, 9, 15, 14, 29, 4, 15, 29]
# 	pattern   11 : 0.068 [29, 29, 4, 9, 4, 29, 1, 4, 14, 29, 4, 15, 29]
# 	pattern   12 : 0.342 [29, 29, 4, 11, 4, 29, 9, 4, 14, 29, 4, 15, 29]
# 	pattern   14 : 0.073 [29, 29, 15, 9, 17, 29, 1, 15, 14, 29, 11, 15, 29]
# application 3
# 	pattern    1 : 0.376 [15, 15, 29, 29, 29]
# 	pattern    5 : 0.624 [17, 15, 29, 29, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  2 0 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 1 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 12 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 5 2 1.0
# removed_columns_count 7
# GAP # iterations : 2 master obj val : 1646.6175211656962
# n_most,u_most,i_most,z_most =  0 0 6 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 1646.6175211656962
# n_most,u_most,i_most,z_most =  1 6 2 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1646.6175211656962
# n_most,u_most,i_most,z_most =  3 1 15 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 1646.6175211656962
# n_most,u_most,i_most,z_most =  0 1 6 1.0
# removed_columns_count 5
# GAP # iterations : 1 master obj val : 1646.6175211656962
# n_most,u_most,i_most,z_most =  3 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 1 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1646.6175211656962
# n_most,u_most,i_most,z_most =  0 4 4 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1646.6175211656962
# n_most,u_most,i_most,z_most =  0 5 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 7 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 8 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 10 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 7 3 0.9622940572709496
# removed_columns_count 2
# GAP # iterations : 3 master obj val : 1646.5788347769972
# n_most,u_most,i_most,z_most =  2 10 4 0.9534052386866585
# removed_columns_count 10
# GAP # iterations : 1 master obj val : 1646.616730072816
# ... solving restricted compact model
# new solution found: z = 1756.0 , time = 3.178815583999949
# new solution found: z = 1737.0 , time = 3.181537500000104
# new solution found: z = 1729.0 , time = 3.187144750000016
# new solution found: z = 1708.0 , time = 3.187333042000091
# new solution found: z = 1700.0 , time = 3.1873875839999073
# new solution found: z = 1700.0 , time = 3.1978058750000855
# new solution found: z = 1708.0 , time = 3.197853208999959
# 3.243 result (0.07508993148803711, 'OPTIMAL', 52.0, 1700.0, None)
#
# --------------------------------------------------------------------------------
#
# 9 5 apps, DATASET_2/networks/network_030_c_rp_4.dat DATASET_2/apps_merged_FINAL/id_0009.dat
#
# STOP, gap < 0.1 %
# #iterations 19 LR_dual_bound 1960.4730401295872 CG_time 4.708
#
# application 0
# 	pattern   13 : 0.001 [29, 29, 12, 16, 15, 12, 9, 29, 29, 29, 10, 29]
# 	pattern   14 : 0.466 [29, 29, 16, 15, 7, 6, 14, 29, 29, 29, 4, 29]
# 	pattern   15 : 0.198 [29, 29, 16, 15, 7, 6, 9, 29, 29, 29, 2, 29]
# 	pattern   16 : 0.131 [29, 29, 12, 16, 15, 14, 9, 29, 29, 29, 4, 29]
# 	pattern   17 : 0.043 [29, 29, 9, 15, 16, 6, 14, 29, 29, 29, 2, 29]
# 	pattern   18 : 0.161 [29, 29, 16, 15, 7, 6, 14, 29, 29, 29, 2, 29]
# application 1
# 	pattern    7 : 1.000 [29, 10, 12, 10, 10]
# application 2
# 	pattern   14 : 0.133 [29, 0, 29, 29, 2, 5, 14, 29, 29, 29, 29, 6, 29, 29, 12]
# 	pattern   17 : 0.576 [29, 0, 29, 29, 2, 15, 5, 29, 29, 29, 29, 0, 29, 29, 12]
# 	pattern   18 : 0.082 [29, 10, 29, 29, 2, 15, 5, 29, 29, 29, 29, 6, 29, 29, 12]
# 	pattern   19 : 0.209 [29, 0, 29, 29, 10, 15, 5, 29, 29, 29, 29, 6, 29, 29, 12]
# application 3
# 	pattern    2 : 0.269 [29, 4, 6, 2, 2]
# 	pattern   12 : 0.035 [29, 5, 6, 2, 2]
# 	pattern   13 : 0.485 [29, 15, 0, 2, 10]
# 	pattern   14 : 0.211 [29, 4, 0, 2, 10]
# application 4
# 	pattern   10 : 0.435 [29, 29, 29, 12, 16, 9, 29, 12, 12]
# 	pattern   12 : 0.212 [29, 29, 29, 10, 5, 9, 29, 13, 12]
# 	pattern   16 : 0.040 [29, 29, 29, 10, 9, 14, 29, 12, 2]
# 	pattern   17 : 0.212 [29, 29, 29, 10, 16, 14, 29, 13, 2]
# 	pattern   18 : 0.102 [29, 29, 29, 10, 5, 14, 29, 12, 12]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  1 1 10 1.0
# removed_columns_count 5
# GAP # iterations : 1 master obj val : 1961.7035533985397
# n_most,u_most,i_most,z_most =  4 2 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 6 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 2 12 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 1961.7035533985395
# n_most,u_most,i_most,z_most =  0 8 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 9 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 11 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 8 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 9 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 12 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 3 10 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 13 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 4 10 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 14 12 1.0
# removed_columns_count 6
# GAP # iterations : 1 master obj val : 1961.7035533985395
# n_most,u_most,i_most,z_most =  3 3 2 0.9999999999999999
# removed_columns_count 6
# GAP # iterations : 1 master obj val : 1961.7035533985395
# n_most,u_most,i_most,z_most =  2 1 0 0.9176147683908139
# removed_columns_count 8
# GAP # iterations : 3 master obj val : 1961.6812824932247
# n_most,u_most,i_most,z_most =  0 2 16 0.8020304568527917
# removed_columns_count 13
# GAP # iterations : 2 master obj val : 1961.6902358250863
# n_most,u_most,i_most,z_most =  0 3 15 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 1961.6902358250868
# n_most,u_most,i_most,z_most =  2 5 15 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1961.6902358250868
# n_most,u_most,i_most,z_most =  2 6 5 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1961.6902358250868
# n_most,u_most,i_most,z_most =  0 6 14 0.9159370916793095
# removed_columns_count 2
# GAP # iterations : 3 master obj val : 1961.790077194609
# ... solving restricted compact model
# 2.745 result (0.004261970520019531, 'INFEASIBLE', 0.0, None, None)
#
# --------------------------------------------------------------------------------
#
# 10 5 apps, DATASET_2/networks/network_030_a_rp_3.dat DATASET_2/apps_merged_FINAL/id_0010.dat
#
# STOP, gap < 0.1 %
# #iterations 15 LR_dual_bound 1728.0944454958621 CG_time 4.050
#
# application 0
# 	pattern    1 : 0.284 [29, 6, 1, 17, 9, 17, 29, 29, 7, 6]
# 	pattern   14 : 0.716 [29, 6, 1, 17, 8, 17, 29, 29, 13, 6]
# application 1
# 	pattern    1 : 0.068 [29, 29, 29, 6, 29, 29, 9, 29, 29, 17, 29]
# 	pattern    9 : 0.203 [29, 29, 29, 6, 29, 29, 4, 29, 29, 17, 29]
# 	pattern   13 : 0.729 [29, 29, 29, 0, 29, 29, 4, 29, 29, 17, 29]
# application 2
# 	pattern    2 : 0.305 [29, 8, 29, 7]
# 	pattern    3 : 0.586 [29, 7, 29, 7]
# 	pattern    8 : 0.062 [29, 13, 29, 8]
# 	pattern   10 : 0.046 [29, 13, 29, 7]
# application 3
# 	pattern    7 : 0.723 [29, 29, 5, 29, 9, 29, 29, 0, 0, 29, 29, 29, 29, 14, 29]
# 	pattern   10 : 0.098 [29, 29, 5, 29, 7, 29, 29, 0, 0, 29, 29, 29, 29, 13, 29]
# 	pattern   15 : 0.179 [29, 29, 8, 29, 9, 29, 29, 1, 1, 29, 29, 29, 29, 5, 29]
# application 4
# 	pattern    1 : 0.012 [17, 1, 9, 1, 29, 7, 29, 29, 29]
# 	pattern    7 : 0.107 [17, 1, 4, 5, 29, 14, 29, 29, 29]
# 	pattern   10 : 0.256 [17, 1, 7, 5, 29, 13, 29, 29, 29]
# 	pattern   12 : 0.290 [17, 1, 9, 16, 29, 13, 29, 29, 29]
# 	pattern   14 : 0.303 [17, 1, 9, 14, 29, 8, 29, 29, 29]
# 	pattern   15 : 0.031 [9, 1, 8, 5, 29, 13, 29, 29, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  2 2 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 6 1.0
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 1729.0244804905583
# n_most,u_most,i_most,z_most =  4 1 1 1.0
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 1729.0244804905583
# n_most,u_most,i_most,z_most =  0 2 1 1.0
# removed_columns_count 5
# GAP # iterations : 1 master obj val : 1729.0244804905583
# n_most,u_most,i_most,z_most =  4 4 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 17 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 5 17 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 7 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 5 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 9 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 9 6 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1729.0244804905583
# n_most,u_most,i_most,z_most =  3 11 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 4 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 12 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 5 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 7 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 9 17 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 1729.0244804905583
# n_most,u_most,i_most,z_most =  1 10 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 0 17 0.9692307692307691
# removed_columns_count 4
#
# INFEASIBLE INSTANCE : we are still using a dummy column, return 1.512
#
# --------------------------------------------------------------------------------
#
# 11 5 apps, DATASET_2/networks/network_030_d_rp_0.dat DATASET_2/apps_merged_FINAL/id_0011.dat
#
# STOP, gap < 0.1 %
# #iterations 31 LR_dual_bound 2330.0750369417715 CG_time 23.084
#
# application 0
# 	pattern   17 : 0.554 [29, 9, 29, 15, 15, 15, 0, 29, 2, 29, 29, 29, 29, 29]
# 	pattern   19 : 0.157 [29, 9, 29, 15, 15, 15, 13, 29, 14, 29, 29, 29, 29, 29]
# 	pattern   24 : 0.036 [29, 9, 29, 15, 15, 15, 13, 29, 2, 29, 29, 29, 29, 29]
# 	pattern   25 : 0.253 [29, 9, 29, 15, 17, 15, 0, 29, 2, 29, 29, 29, 29, 29]
# application 1
# 	pattern   11 : 0.012 [29, 8, 13, 29, 29, 5, 29, 29, 17, 29, 29, 29, 0, 7, 4]
# 	pattern   21 : 0.319 [29, 8, 14, 29, 29, 5, 29, 29, 2, 29, 29, 29, 0, 7, 4]
# 	pattern   23 : 0.077 [29, 10, 8, 29, 29, 4, 29, 29, 5, 29, 29, 29, 1, 7, 11]
# 	pattern   24 : 0.053 [29, 10, 8, 29, 29, 4, 29, 29, 5, 29, 29, 29, 0, 9, 11]
# 	pattern   26 : 0.163 [29, 10, 13, 29, 29, 4, 29, 29, 5, 29, 29, 29, 8, 7, 11]
# 	pattern   27 : 0.085 [29, 8, 13, 29, 29, 5, 29, 29, 2, 29, 29, 29, 0, 7, 4]
# 	pattern   28 : 0.014 [29, 13, 8, 29, 29, 15, 29, 29, 5, 29, 29, 29, 18, 7, 11]
# 	pattern   30 : 0.162 [29, 10, 8, 29, 29, 4, 29, 29, 5, 29, 29, 29, 0, 7, 11]
# 	pattern   31 : 0.114 [29, 10, 0, 29, 29, 4, 29, 29, 5, 29, 29, 29, 8, 9, 11]
# application 2
# 	pattern    1 : 0.110 [29, 15, 15, 6]
# 	pattern   10 : 0.890 [29, 17, 15, 6]
# application 3
# 	pattern   16 : 0.025 [29, 0, 29, 29, 4, 2, 4, 17, 11, 15, 3]
# 	pattern   19 : 0.054 [29, 10, 29, 29, 13, 13, 18, 1, 11, 9, 3]
# 	pattern   21 : 0.317 [29, 13, 29, 29, 4, 11, 10, 2, 5, 7, 3]
# 	pattern   23 : 0.111 [29, 10, 29, 29, 4, 13, 18, 8, 8, 1, 4]
# 	pattern   25 : 0.154 [29, 10, 29, 29, 13, 13, 18, 1, 5, 7, 3]
# 	pattern   27 : 0.132 [29, 10, 29, 29, 4, 13, 18, 17, 0, 15, 4]
# 	pattern   29 : 0.111 [29, 0, 29, 29, 4, 2, 4, 8, 5, 1, 3]
# 	pattern   30 : 0.058 [29, 10, 29, 29, 4, 13, 18, 8, 11, 1, 3]
# 	pattern   31 : 0.038 [29, 8, 29, 29, 17, 2, 4, 1, 13, 9, 13]
# application 4
# 	pattern   11 : 0.382 [15, 29, 29, 4, 2, 2, 29, 29]
# 	pattern   22 : 0.618 [15, 29, 29, 18, 13, 17, 29, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  4 0 15 1.0
# removed_columns_count 12
# GAP # iterations : 1 master obj val : 2330.451294874999
# n_most,u_most,i_most,z_most =  0 1 9 1.0
# removed_columns_count 8
# GAP # iterations : 1 master obj val : 2330.451294874999
# n_most,u_most,i_most,z_most =  1 3 29 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 2330.451294874999
# n_most,u_most,i_most,z_most =  1 4 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 3 29 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 2330.451294874999
# n_most,u_most,i_most,z_most =  2 2 15 1.0
# removed_columns_count 7
# GAP # iterations : 1 master obj val : 2330.451294874999
# n_most,u_most,i_most,z_most =  2 3 6 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 9 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 11 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 15 1.0
# removed_columns_count 10
# GAP # iterations : 1 master obj val : 2330.451294874999
# n_most,u_most,i_most,z_most =  0 5 15 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 7 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 9 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 11 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 13 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 1 17 0.8900575458323126
# removed_columns_count 3
# GAP # iterations : 3 master obj val : 2331.396469523747
# n_most,u_most,i_most,z_most =  1 13 7 0.9210452409077238
# removed_columns_count 14
# GAP # iterations : 1 master obj val : 2331.4001019331026
# n_most,u_most,i_most,z_most =  3 4 4 0.9194709358004955
# removed_columns_count 17
# GAP # iterations : 2 master obj val : 2331.5720234454866
# n_most,u_most,i_most,z_most =  0 6 0 0.8752949100396685
# removed_columns_count 3
# GAP # iterations : 2 master obj val : 2332.2257214263927
# n_most,u_most,i_most,z_most =  0 8 2 0.9442292778385395
# removed_columns_count 2
# GAP # iterations : 2 master obj val : 2332.2493767479805
# n_most,u_most,i_most,z_most =  3 10 3 0.7261709589613814
# removed_columns_count 5
# GAP # iterations : 4 master obj val : 2332.765720127546
# n_most,u_most,i_most,z_most =  4 3 18 0.7034154359854833
# removed_columns_count 8
# GAP # iterations : 3 master obj val : 2335.399988955896
# ... solving restricted compact model
# 13.468 result (0.00846099853515625, 'INFEASIBLE', 1.0, None, None)
#
# --------------------------------------------------------------------------------
#
# 12 6 apps, DATASET_2/networks/network_030_a_rp_4.dat DATASET_2/apps_merged_FINAL/id_0012.dat
#
# STOP, gap < 0.1 %
# #iterations 15 LR_dual_bound 2019.7383296787862 CG_time 9.484
#
# application 0
# 	pattern    6 : 0.134 [29, 1, 6]
# 	pattern   11 : 0.613 [29, 17, 6]
# 	pattern   12 : 0.253 [29, 1, 17]
# application 1
# 	pattern    6 : 0.086 [29, 16, 15, 13, 29, 29, 10, 6, 6, 6, 29, 6, 2, 29, 9]
# 	pattern   10 : 0.652 [29, 3, 14, 9, 29, 29, 10, 17, 1, 1, 29, 1, 2, 29, 5]
# 	pattern   11 : 0.126 [29, 16, 15, 9, 29, 29, 10, 17, 1, 7, 29, 6, 2, 29, 14]
# 	pattern   13 : 0.134 [29, 9, 15, 13, 29, 29, 8, 6, 6, 6, 29, 6, 17, 29, 9]
# 	pattern   15 : 0.002 [29, 16, 15, 13, 29, 29, 10, 6, 6, 6, 29, 6, 2, 29, 14]
# application 2
# 	pattern    3 : 0.910 [29, 29, 29, 15, 29, 29]
# 	pattern    4 : 0.090 [29, 29, 29, 5, 29, 29]
# application 3
# 	pattern    3 : 0.189 [29, 15, 8, 29]
# 	pattern    7 : 0.457 [29, 11, 7, 29]
# 	pattern    9 : 0.354 [29, 11, 8, 29]
# application 4
# 	pattern    6 : 0.028 [29, 16, 29, 6, 6, 10, 17, 29, 6, 6, 29, 1, 29, 29, 3]
# 	pattern   10 : 0.155 [29, 16, 29, 8, 1, 3, 7, 29, 17, 1, 29, 1, 29, 29, 13]
# 	pattern   12 : 0.264 [29, 9, 29, 6, 6, 3, 7, 29, 6, 6, 29, 6, 29, 29, 17]
# 	pattern   13 : 0.196 [29, 9, 29, 8, 1, 13, 7, 29, 17, 1, 29, 1, 29, 29, 17]
# 	pattern   14 : 0.265 [29, 9, 29, 6, 6, 3, 8, 29, 6, 6, 29, 1, 29, 29, 17]
# 	pattern   15 : 0.093 [29, 16, 29, 8, 17, 13, 7, 29, 17, 1, 29, 1, 29, 29, 3]
# application 5
# 	pattern   10 : 0.485 [29, 13, 3, 29, 10]
# 	pattern   13 : 0.432 [29, 10, 2, 29, 7]
# 	pattern   14 : 0.083 [29, 13, 17, 29, 10]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  3 3 29 1.0000000000000004
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 2021.1566927118247
# n_most,u_most,i_most,z_most =  4 2 29 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 2021.1566927118247
# n_most,u_most,i_most,z_most =  5 3 29 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 2021.1566927118247
# n_most,u_most,i_most,z_most =  4 12 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 13 29 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 2021.1566927118247
# n_most,u_most,i_most,z_most =  1 5 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 10 29 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 2021.1566927118247
# n_most,u_most,i_most,z_most =  2 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 4 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 5 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 3 15 0.9103467039623551
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 2021.2013194268688
# n_most,u_most,i_most,z_most =  3 1 11 0.836412434068989
# removed_columns_count 7
# GAP # iterations : 2 master obj val : 2021.2955417950375
# n_most,u_most,i_most,z_most =  0 1 17 0.8779465357466095
# removed_columns_count 9
# GAP # iterations : 1 master obj val : 2021.4396386579676
# n_most,u_most,i_most,z_most =  0 2 6 0.9096697240887198
# removed_columns_count 3
# GAP # iterations : 3 master obj val : 2021.5191359118337
# n_most,u_most,i_most,z_most =  4 11 1 0.7677614304048641
# removed_columns_count 7
# GAP # iterations : 6 master obj val : 2022.8293683905563
# n_most,u_most,i_most,z_most =  1 3 9 0.9011388405315301
# removed_columns_count 10
# GAP # iterations : 1 master obj val : 2024.273372782454
# n_most,u_most,i_most,z_most =  1 7 17 0.8783549017467696
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 2024.552461033258
# n_most,u_most,i_most,z_most =  1 8 1 0.9180275514166374
# removed_columns_count 3
# GAP # iterations : 2 master obj val : 2024.5843337497784
# n_most,u_most,i_most,z_most =  5 1 13 0.8704493753807683
# removed_columns_count 5
# GAP # iterations : 1 master obj val : 2025.12156760596
# n_most,u_most,i_most,z_most =  1 6 10 0.8857958904384508
# removed_columns_count 4
# GAP # iterations : 3 master obj val : 2025.5383731601441
# n_most,u_most,i_most,z_most =  1 12 2 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 5 3 0.853853049117852
# removed_columns_count 9
# GAP # iterations : 2 master obj val : 2026.1501543930997
# n_most,u_most,i_most,z_most =  1 9 1 0.7997292989697725
# removed_columns_count 3
# GAP # iterations : 9 master obj val : 2027.3854154467338
# ... solving restricted compact model
# 15.829 result (0.0027379989624023438, 'INFEASIBLE', 0.0, None, None)
#
# --------------------------------------------------------------------------------
#
# 13 6 apps, DATASET_2/networks/network_030_b_rp_2.dat DATASET_2/apps_merged_FINAL/id_0013.dat
#
# STOP, gap < 0.1 %
# #iterations 20 LR_dual_bound 3042.8689242534006 CG_time 12.629
#
# application 0
# 	pattern   12 : 0.423 [29, 29, 29, 12, 1, 10, 19, 9, 19, 29, 29, 29]
# 	pattern   13 : 0.383 [29, 29, 29, 12, 14, 6, 9, 9, 9, 29, 29, 29]
# 	pattern   18 : 0.193 [29, 29, 29, 12, 14, 10, 19, 9, 19, 29, 29, 29]
# application 1
# 	pattern    9 : 0.054 [29, 6, 12, 29, 0, 9, 29, 10, 29, 19, 9]
# 	pattern   16 : 0.166 [29, 7, 10, 29, 12, 9, 29, 3, 29, 9, 19]
# 	pattern   18 : 0.470 [29, 6, 12, 29, 13, 9, 29, 3, 29, 19, 9]
# 	pattern   19 : 0.000 [29, 7, 10, 29, 0, 9, 29, 3, 29, 9, 19]
# 	pattern   20 : 0.310 [29, 6, 12, 29, 0, 19, 29, 3, 29, 19, 9]
# application 2
# 	pattern    2 : 0.119 [29, 13, 29, 2, 29, 18, 29, 12, 5]
# 	pattern   14 : 0.267 [29, 7, 29, 2, 29, 18, 29, 13, 5]
# 	pattern   15 : 0.009 [29, 13, 29, 2, 29, 10, 29, 10, 19]
# 	pattern   17 : 0.553 [29, 13, 29, 2, 29, 18, 29, 0, 5]
# 	pattern   18 : 0.014 [29, 13, 29, 2, 29, 1, 29, 0, 19]
# 	pattern   20 : 0.037 [29, 18, 29, 5, 29, 6, 29, 12, 9]
# application 3
# 	pattern   10 : 0.056 [29, 6, 29, 12, 10, 10, 29, 12, 4, 29, 11]
# 	pattern   11 : 0.065 [29, 13, 29, 4, 17, 10, 29, 0, 11, 29, 11]
# 	pattern   14 : 0.425 [29, 0, 29, 4, 17, 10, 29, 10, 4, 29, 11]
# 	pattern   15 : 0.002 [29, 0, 29, 4, 10, 10, 29, 3, 4, 29, 11]
# 	pattern   19 : 0.003 [29, 0, 29, 4, 10, 10, 29, 10, 11, 29, 11]
# 	pattern   20 : 0.449 [29, 0, 29, 10, 10, 10, 29, 4, 11, 29, 11]
# application 4
# 	pattern   16 : 0.103 [11, 29, 18, 1, 12, 29]
# 	pattern   17 : 0.422 [11, 29, 2, 1, 15, 29]
# 	pattern   19 : 0.264 [11, 29, 1, 18, 12, 29]
# 	pattern   20 : 0.211 [11, 29, 18, 1, 3, 29]
# application 5
# 	pattern    7 : 0.181 [29, 29, 2, 2, 29, 3, 18, 29, 29, 9, 29, 4]
# 	pattern   12 : 0.037 [29, 29, 5, 9, 29, 3, 14, 29, 29, 9, 29, 4]
# 	pattern   14 : 0.126 [29, 29, 2, 14, 29, 15, 14, 29, 29, 19, 29, 4]
# 	pattern   15 : 0.280 [29, 29, 9, 14, 29, 6, 14, 29, 29, 19, 29, 4]
# 	pattern   16 : 0.213 [29, 29, 5, 14, 29, 3, 14, 29, 29, 19, 29, 4]
# 	pattern   18 : 0.052 [29, 29, 2, 14, 29, 3, 14, 29, 29, 9, 29, 4]
# 	pattern   19 : 0.009 [29, 29, 2, 2, 29, 3, 18, 29, 29, 19, 29, 4]
# 	pattern   20 : 0.102 [29, 29, 14, 2, 29, 6, 18, 29, 29, 19, 29, 4]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  1 0 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 0 11 1.0
# removed_columns_count 11
# GAP # iterations : 1 master obj val : 3044.9753028389027
# n_most,u_most,i_most,z_most =  5 4 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 8 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 10 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 12 1.0
# removed_columns_count 7
# GAP # iterations : 1 master obj val : 3044.9753028389027
# n_most,u_most,i_most,z_most =  3 5 10 1.0
# removed_columns_count 5
# GAP # iterations : 1 master obj val : 3044.9753028389027
# n_most,u_most,i_most,z_most =  0 7 9 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 3044.9753028389027
# n_most,u_most,i_most,z_most =  3 6 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 8 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 11 4 1.0
# removed_columns_count 6
# GAP # iterations : 1 master obj val : 3044.9753028389027
# n_most,u_most,i_most,z_most =  3 9 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 10 11 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 3044.9753028389027
# n_most,u_most,i_most,z_most =  0 9 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 10 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 2 29 0.9999999999999999
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 4 29 0.9999999999999999
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 1 29 0.9999999999999999
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 6 29 0.9999999999999999
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 3044.9753028389027
# n_most,u_most,i_most,z_most =  2 3 2 0.962717284853855
# removed_columns_count 12
# GAP # iterations : 1 master obj val : 3045.002131492525
# n_most,u_most,i_most,z_most =  2 5 18 0.968167607089123
# removed_columns_count 4
# GAP # iterations : 2 master obj val : 3044.9696187174104
# n_most,u_most,i_most,z_most =  2 8 5 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 7 3 0.928383178963215
# removed_columns_count 9
# GAP # iterations : 2 master obj val : 3044.9955049903338
# n_most,u_most,i_most,z_most =  3 1 0 0.9015398957823852
# removed_columns_count 6
# GAP # iterations : 2 master obj val : 3044.955768153624
# n_most,u_most,i_most,z_most =  1 9 19 0.8486952582662325
# removed_columns_count 5
# GAP # iterations : 2 master obj val : 3045.403787670942
# n_most,u_most,i_most,z_most =  5 9 19 0.9732467930078459
# removed_columns_count 9
# GAP # iterations : 2 master obj val : 3045.2743505031385
# n_most,u_most,i_most,z_most =  1 1 6 0.9132617817054871
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 3045.5929607705298
# n_most,u_most,i_most,z_most =  1 2 12 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 10 9 1.0000000000000002
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 3045.5929607705298
# n_most,u_most,i_most,z_most =  3 4 10 0.7365441191944646
# removed_columns_count 4
# GAP # iterations : 3 master obj val : 3045.8508038576792
# ... solving restricted compact model
# 12.734 result (0.0032758712768554688, 'INFEASIBLE', 0.0, None, None)
#
# --------------------------------------------------------------------------------
#
# 14 6 apps, DATASET_2/networks/network_030_b_rp_4.dat DATASET_2/apps_merged_FINAL/id_0014.dat
#
# STOP, gap < 0.1 %
# #iterations 16 LR_dual_bound 1844.7524396335468 CG_time 3.640
#
# application 0
# 	pattern    6 : 0.527 [29, 4, 8, 29]
# 	pattern    7 : 0.385 [29, 5, 11, 29]
# 	pattern   11 : 0.088 [29, 3, 8, 29]
# application 1
# 	pattern    1 : 1.000 [29, 29, 29]
# application 2
# 	pattern    6 : 0.077 [8, 8, 10, 5, 13, 29]
# 	pattern    7 : 0.245 [11, 11, 5, 9, 2, 29]
# 	pattern   13 : 0.636 [8, 8, 10, 9, 2, 29]
# 	pattern   14 : 0.043 [11, 11, 5, 19, 2, 29]
# application 3
# 	pattern    4 : 0.040 [29, 29, 29, 29, 9, 2]
# 	pattern    6 : 0.177 [29, 29, 29, 29, 9, 13]
# 	pattern    7 : 0.303 [29, 29, 29, 29, 19, 2]
# 	pattern    8 : 0.480 [29, 29, 29, 29, 9, 19]
# application 4
# 	pattern    7 : 0.099 [29, 29, 29, 5, 19, 11, 0, 10, 9, 29, 29, 29]
# 	pattern   10 : 0.295 [29, 29, 29, 5, 19, 11, 4, 0, 9, 29, 29, 29]
# 	pattern   11 : 0.392 [29, 29, 29, 5, 19, 11, 4, 0, 10, 29, 29, 29]
# 	pattern   14 : 0.214 [29, 29, 29, 5, 11, 8, 0, 10, 19, 29, 29, 29]
# application 5
# 	pattern    6 : 0.497 [29, 9, 29, 29, 29, 6, 14, 16, 29, 29, 13, 8, 16, 8, 29]
# 	pattern    9 : 0.099 [29, 19, 29, 29, 29, 0, 14, 16, 29, 29, 13, 11, 16, 11, 29]
# 	pattern   10 : 0.101 [29, 16, 29, 29, 29, 0, 14, 9, 29, 29, 13, 8, 11, 8, 29]
# 	pattern   15 : 0.261 [29, 8, 29, 29, 29, 0, 14, 8, 29, 29, 13, 16, 16, 11, 29]
# 	pattern   16 : 0.042 [29, 14, 29, 29, 29, 6, 16, 8, 29, 29, 13, 11, 11, 8, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  3 1 29 1.0000000000000007
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 2 29 1.0000000000000007
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 3 29 1.0000000000000007
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 0 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 1 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 2 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 3 5 1.0000000000000002
# removed_columns_count 8
# GAP # iterations : 1 master obj val : 1846.3374624473686
# n_most,u_most,i_most,z_most =  5 2 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 4 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 8 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 9 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 10 13 1.0000000000000002
# removed_columns_count 6
# GAP # iterations : 1 master obj val : 1846.3374624473686
# n_most,u_most,i_most,z_most =  5 14 29 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 3 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 2 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 6 14 0.9583478933544018
# removed_columns_count 3
# GAP # iterations : 2 master obj val : 1846.26048647384
# n_most,u_most,i_most,z_most =  2 4 2 0.923076923076923
# removed_columns_count 9
# GAP # iterations : 1 master obj val : 1846.402277903767
# n_most,u_most,i_most,z_most =  2 3 9 0.9296398813813036
# removed_columns_count 2
# GAP # iterations : 2 master obj val : 1846.2938724690403
# n_most,u_most,i_most,z_most =  5 12 16 1.0000000000000002
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 1846.2938724690405
# n_most,u_most,i_most,z_most =  5 7 16 0.852401238632447
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 1846.3569558478882
# n_most,u_most,i_most,z_most =  5 11 8 0.8424406508658226
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 1846.6411145457444
# n_most,u_most,i_most,z_most =  5 13 8 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 2 11 0.7304485633144123
# removed_columns_count 8
# GAP # iterations : 1 master obj val : 1847.1525187210214
# ... solving restricted compact model
# new solution found: z = 1987.0 , time = 1.8388352919998852
# new solution found: z = 1971.0 , time = 1.838976582999976
# new solution found: z = 1954.0 , time = 1.840930291999939
# new solution found: z = 1945.0 , time = 1.841114874999903
# new solution found: z = 1936.0 , time = 1.8456119999998464
# 1.853 result (0.022418975830078125, 'OPTIMAL', 1.0, 1936.0, None)
#
# --------------------------------------------------------------------------------
#
# 15 7 apps, DATASET_2/networks/network_030_d_rp_1.dat DATASET_2/apps_merged_FINAL/id_0015.dat
#
# STOP, gap < 0.1 %
# #iterations 19 LR_dual_bound 2206.187160778566 CG_time 11.184
#
# application 0
# 	pattern    8 : 0.035 [5, 5, 5, 29, 3, 13, 18, 2, 29, 29, 29, 29, 29]
# 	pattern   11 : 0.143 [5, 5, 5, 29, 3, 10, 18, 2, 29, 29, 29, 29, 29]
# 	pattern   12 : 0.049 [5, 5, 5, 29, 15, 6, 10, 3, 29, 29, 29, 29, 29]
# 	pattern   13 : 0.455 [5, 5, 5, 29, 11, 13, 10, 3, 29, 29, 29, 29, 29]
# 	pattern   14 : 0.085 [5, 5, 5, 29, 3, 6, 18, 1, 29, 29, 29, 29, 29]
# 	pattern   17 : 0.051 [5, 5, 5, 29, 15, 13, 10, 3, 29, 29, 29, 29, 29]
# 	pattern   18 : 0.182 [5, 5, 5, 29, 15, 17, 18, 2, 29, 29, 29, 29, 29]
# application 1
# 	pattern    7 : 0.037 [29, 3, 13, 10, 29, 6, 1, 4, 29]
# 	pattern    8 : 0.189 [29, 17, 14, 15, 29, 17, 13, 6, 29]
# 	pattern    9 : 0.506 [29, 15, 14, 18, 29, 6, 15, 17, 29]
# 	pattern   12 : 0.217 [29, 7, 8, 9, 29, 5, 13, 6, 29]
# 	pattern   14 : 0.051 [29, 18, 8, 15, 29, 17, 13, 6, 29]
# application 2
# 	pattern    1 : 0.123 [29, 15, 6]
# 	pattern    5 : 0.224 [29, 9, 3]
# 	pattern    6 : 0.643 [29, 11, 6]
# 	pattern    8 : 0.009 [29, 9, 5]
# application 3
# 	pattern   11 : 0.020 [15, 29, 29, 17, 29, 4, 8, 2, 29, 3, 10, 29, 29, 29]
# 	pattern   12 : 0.256 [15, 29, 29, 5, 29, 17, 13, 6, 29, 3, 10, 29, 29, 29]
# 	pattern   13 : 0.279 [4, 29, 29, 17, 29, 5, 5, 2, 29, 6, 10, 29, 29, 29]
# 	pattern   15 : 0.151 [15, 29, 29, 5, 29, 4, 18, 2, 29, 6, 10, 29, 29, 29]
# 	pattern   16 : 0.046 [15, 29, 29, 17, 29, 5, 5, 2, 29, 3, 10, 29, 29, 29]
# 	pattern   17 : 0.066 [4, 29, 29, 10, 29, 5, 5, 2, 29, 6, 17, 29, 29, 29]
# 	pattern   19 : 0.183 [15, 29, 29, 5, 29, 4, 8, 2, 29, 6, 10, 29, 29, 29]
# application 4
# 	pattern    1 : 1.000 [29, 29, 0, 29]
# application 5
# 	pattern    1 : 0.164 [5, 5, 29, 4, 29, 29, 29, 29, 29, 29, 29]
# 	pattern    7 : 0.666 [17, 17, 29, 4, 29, 29, 29, 29, 29, 29, 29]
# 	pattern    8 : 0.170 [2, 4, 29, 4, 29, 29, 29, 29, 29, 29, 29]
# application 6
# 	pattern    5 : 0.859 [29, 29, 14, 29, 29]
# 	pattern    7 : 0.141 [29, 29, 18, 29, 29]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  0 0 5 1.0000000000000007
# removed_columns_count 6
# GAP # iterations : 1 master obj val : 2207.9152464812064
# n_most,u_most,i_most,z_most =  4 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 1 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  6 0 29 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 2 0 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 1 5 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 2 5 1.0
# ...
#
# application 0
# 	pattern   19 : 0.120 [69, 69, 29, 69, 69, 7, 69, 69, 36]
# 	pattern   21 : 0.055 [69, 69, 3, 69, 69, 1, 69, 69, 36]
# 	pattern   25 : 0.084 [69, 69, 13, 69, 69, 45, 69, 69, 36]
# 	pattern   26 : 0.334 [69, 69, 29, 69, 69, 19, 69, 69, 36]
# 	pattern   28 : 0.006 [69, 69, 13, 69, 69, 19, 69, 69, 15]
# 	pattern   29 : 0.250 [69, 69, 13, 69, 69, 1, 69, 69, 36]
# 	pattern   30 : 0.097 [69, 69, 22, 69, 69, 1, 69, 69, 36]
# 	pattern   31 : 0.054 [69, 69, 29, 69, 69, 1, 69, 69, 36]
# application 1
# 	pattern    1 : 1.000 [69, 69, 69]
# application 2
# 	pattern   20 : 0.490 [69, 29, 11, 43, 2, 0, 69, 43, 41, 69, 69, 69]
# 	pattern   22 : 0.231 [69, 22, 11, 43, 2, 0, 69, 15, 23, 69, 69, 69]
# 	pattern   23 : 0.197 [69, 22, 11, 43, 2, 21, 69, 43, 23, 69, 69, 69]
# 	pattern   25 : 0.037 [69, 13, 23, 12, 35, 35, 69, 43, 41, 69, 69, 69]
# 	pattern   31 : 0.044 [69, 29, 23, 9, 35, 35, 69, 43, 13, 69, 69, 69]
# application 3
# 	pattern   18 : 0.285 [69, 8, 69, 69, 2, 16, 2]
# 	pattern   20 : 0.646 [69, 8, 69, 69, 15, 16, 15]
# 	pattern   25 : 0.069 [69, 34, 69, 69, 15, 7, 15]
# application 4
# 	pattern   17 : 0.280 [69, 2, 11, 69, 32, 69, 69]
# 	pattern   21 : 0.718 [69, 21, 18, 69, 10, 69, 69]
# 	pattern   30 : 0.002 [69, 2, 18, 69, 34, 69, 69]
# application 5
# 	pattern   22 : 0.083 [69, 69, 69, 4, 69, 69, 12, 69, 69]
# 	pattern   23 : 0.375 [69, 69, 69, 26, 69, 69, 3, 69, 69]
# 	pattern   24 : 0.022 [69, 69, 69, 32, 69, 69, 46, 69, 69]
# 	pattern   27 : 0.300 [69, 69, 69, 26, 69, 69, 46, 69, 69]
# 	pattern   30 : 0.132 [69, 69, 69, 19, 69, 69, 12, 69, 69]
# 	pattern   31 : 0.087 [69, 69, 69, 26, 69, 69, 12, 69, 69]
# application 6
# 	pattern   21 : 0.169 [69, 69, 3, 45, 15, 69, 39]
# 	pattern   23 : 0.714 [69, 69, 3, 25, 36, 69, 39]
# 	pattern   28 : 0.117 [69, 69, 3, 4, 36, 69, 39]
# application 7
# 	pattern   21 : 0.138 [69, 69, 16, 69, 69, 4, 69, 36, 69]
# 	pattern   23 : 0.162 [69, 69, 37, 69, 69, 7, 69, 14, 69]
# 	pattern   28 : 0.146 [69, 69, 16, 69, 69, 38, 69, 36, 69]
# 	pattern   29 : 0.553 [69, 69, 37, 69, 69, 38, 69, 14, 69]
# application 8
# 	pattern   17 : 0.247 [69, 64, 7, 1, 36, 69, 20, 69]
# 	pattern   19 : 0.264 [69, 14, 26, 5, 14, 69, 10, 69]
# 	pattern   23 : 0.200 [69, 0, 28, 5, 14, 69, 7, 69]
# 	pattern   25 : 0.021 [69, 64, 28, 5, 14, 69, 20, 69]
# 	pattern   29 : 0.090 [69, 14, 16, 24, 2, 69, 10, 69]
# 	pattern   30 : 0.143 [69, 64, 28, 5, 14, 69, 10, 69]
# 	pattern   31 : 0.036 [69, 0, 26, 5, 14, 69, 16, 69]
# application 9
# 	pattern    4 : 0.084 [69, 10, 69]
# 	pattern    7 : 0.849 [69, 28, 69]
# 	pattern   21 : 0.068 [69, 32, 69]
# application 10
# 	pattern   24 : 0.327 [69, 32, 31, 69, 14, 38, 69, 29]
# 	pattern   26 : 0.512 [69, 25, 5, 69, 14, 4, 69, 29]
# 	pattern   29 : 0.161 [69, 25, 5, 69, 14, 38, 69, 2]
# application 11
# 	pattern   13 : 0.326 [69, 7, 69, 2, 69, 2, 69, 69]
# 	pattern   18 : 0.395 [69, 19, 69, 35, 69, 35, 69, 69]
# 	pattern   21 : 0.279 [69, 19, 69, 35, 69, 2, 69, 69]
# application 12
# 	pattern   15 : 0.540 [69, 37, 6, 35, 0, 35, 69, 69, 46, 69, 18, 69]
# 	pattern   21 : 0.100 [69, 27, 9, 40, 35, 35, 69, 69, 34, 69, 32, 69]
# 	pattern   22 : 0.018 [69, 42, 2, 2, 0, 2, 69, 69, 46, 69, 19, 69]
# 	pattern   23 : 0.022 [69, 27, 9, 35, 35, 35, 69, 69, 12, 69, 11, 69]
# 	pattern   26 : 0.033 [69, 43, 7, 35, 2, 35, 69, 69, 4, 69, 11, 69]
# 	pattern   27 : 0.057 [69, 30, 0, 43, 2, 21, 69, 69, 46, 69, 19, 69]
# 	pattern   28 : 0.059 [69, 43, 20, 2, 35, 2, 69, 69, 34, 69, 19, 69]
# 	pattern   30 : 0.172 [69, 27, 9, 40, 35, 35, 69, 69, 44, 69, 41, 69]
# application 13
# 	pattern   13 : 0.082 [69, 41, 69, 69, 69, 12, 29]
# 	pattern   16 : 0.023 [69, 41, 69, 69, 69, 9, 22]
# 	pattern   23 : 0.679 [69, 23, 69, 69, 69, 12, 22]
# 	pattern   25 : 0.208 [69, 41, 69, 69, 69, 13, 22]
# 	pattern   26 : 0.008 [69, 41, 69, 69, 69, 12, 22]
# application 14
# 	pattern    3 : 0.892 [69, 69, 40, 40, 9, 69]
# 	pattern   22 : 0.108 [69, 69, 15, 15, 45, 69]
# application 15
# 	pattern    1 : 1.000 [69, 69, 69]
# application 16
# 	pattern   23 : 0.134 [15, 69, 35, 69, 3, 69, 69, 37, 37, 30, 34, 69, 69, 69, 69]
# 	pattern   26 : 0.279 [15, 69, 22, 69, 32, 69, 69, 34, 40, 40, 27, 69, 69, 69, 69]
# 	pattern   27 : 0.242 [15, 69, 35, 69, 26, 69, 69, 0, 0, 30, 30, 69, 69, 69, 69]
# 	pattern   28 : 0.109 [15, 69, 29, 69, 9, 69, 69, 30, 37, 30, 34, 69, 69, 69, 69]
# 	pattern   30 : 0.105 [15, 69, 13, 69, 32, 69, 69, 14, 14, 37, 34, 69, 69, 69, 69]
# 	pattern   31 : 0.131 [15, 69, 22, 69, 28, 69, 69, 37, 37, 30, 30, 69, 69, 69, 69]
# application 17
# 	pattern   23 : 0.129 [69, 8, 21, 69, 16, 69, 24, 21, 27]
# 	pattern   24 : 0.144 [69, 43, 21, 69, 16, 69, 24, 21, 42]
# 	pattern   27 : 0.163 [69, 42, 21, 69, 20, 69, 24, 21, 27]
# 	pattern   28 : 0.222 [69, 43, 21, 69, 20, 69, 33, 21, 30]
# 	pattern   29 : 0.220 [69, 43, 21, 69, 20, 69, 24, 21, 27]
# 	pattern   30 : 0.062 [69, 34, 21, 69, 6, 69, 24, 21, 30]
# 	pattern   31 : 0.060 [69, 34, 21, 69, 8, 69, 24, 21, 30]
# application 18
# 	pattern   17 : 0.022 [69, 69, 42, 69, 20, 24, 35, 69, 24, 2, 69, 2, 11]
# 	pattern   19 : 0.162 [69, 69, 42, 69, 6, 14, 35, 69, 24, 2, 69, 2, 26]
# 	pattern   21 : 0.158 [69, 69, 34, 69, 45, 33, 13, 69, 5, 14, 69, 14, 24]
# 	pattern   23 : 0.197 [69, 69, 42, 69, 6, 0, 35, 69, 24, 2, 69, 2, 1]
# 	pattern   27 : 0.002 [69, 69, 34, 69, 19, 14, 35, 69, 0, 21, 69, 21, 7]
# 	pattern   28 : 0.075 [69, 69, 45, 69, 19, 14, 29, 69, 24, 2, 69, 2, 1]
# 	pattern   29 : 0.051 [69, 69, 26, 69, 43, 2, 35, 69, 5, 14, 69, 14, 24]
# 	pattern   30 : 0.326 [69, 69, 42, 69, 6, 14, 35, 69, 24, 2, 69, 2, 1]
# 	pattern   31 : 0.008 [69, 69, 34, 69, 8, 2, 22, 69, 5, 14, 69, 14, 16]
# application 19
# 	pattern   21 : 0.025 [69, 69, 69, 69, 69, 36, 32, 40]
# 	pattern   27 : 0.539 [69, 69, 69, 69, 69, 15, 32, 40]
# 	pattern   28 : 0.228 [69, 69, 69, 69, 69, 15, 16, 15]
# 	pattern   29 : 0.208 [69, 69, 69, 69, 69, 36, 0, 40]
# application 20
# 	pattern   24 : 0.016 [69, 35, 33, 32, 31, 30, 38, 69, 69]
# 	pattern   27 : 0.177 [69, 2, 2, 20, 0, 30, 4, 69, 69]
# 	pattern   28 : 0.596 [69, 35, 33, 14, 31, 30, 4, 69, 69]
# 	pattern   29 : 0.050 [69, 2, 2, 20, 0, 43, 9, 69, 69]
# 	pattern   30 : 0.161 [69, 35, 33, 28, 31, 30, 25, 69, 69]
# application 21
# 	pattern   22 : 0.170 [69, 4, 13, 44, 12, 69, 69, 69]
# 	pattern   23 : 0.696 [69, 45, 22, 13, 12, 69, 69, 69]
# 	pattern   28 : 0.034 [69, 4, 13, 39, 44, 69, 69, 69]
# 	pattern   31 : 0.099 [69, 38, 22, 13, 12, 69, 69, 69]
# application 22
# 	pattern    9 : 0.260 [69, 69, 41]
# 	pattern   12 : 0.740 [69, 69, 23]
# application 23
# 	pattern   22 : 0.004 [14, 14, 34, 12, 69]
# 	pattern   25 : 0.007 [14, 14, 30, 25, 69]
# 	pattern   26 : 0.252 [0, 21, 34, 44, 69]
# 	pattern   27 : 0.111 [40, 35, 27, 46, 69]
# 	pattern   28 : 0.053 [21, 21, 6, 13, 69]
# 	pattern   30 : 0.439 [21, 21, 34, 44, 69]
# 	pattern   31 : 0.134 [14, 14, 5, 12, 69]
#
# rounding_subMIPing
#
# n_most,u_most,i_most,z_most =  5 0 69 1.0000000000000024
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 1 69 1.0000000000000024
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 2 69 1.0000000000000024
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 4 69 1.0000000000000024
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 8052.111053260891
# n_most,u_most,i_most,z_most =  18 3 69 1.000000000000003
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  18 10 69 1.000000000000003
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  12 0 69 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  12 7 69 1.0000000000000002
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 8052.111053260891
# n_most,u_most,i_most,z_most =  12 11 69 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  5 5 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 0 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  7 3 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  10 4 14 1.0
# removed_columns_count 16
# GAP # iterations : 1 master obj val : 8052.111053260891
# n_most,u_most,i_most,z_most =  2 10 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  20 0 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  15 1 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  2 11 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  7 4 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  9 2 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  15 2 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  19 0 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  14 1 69 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 8052.111053260891
# n_most,u_most,i_most,z_most =  6 0 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  13 3 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 3 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  7 6 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  14 5 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 5 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 0 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  21 5 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  21 6 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  6 2 3 1.0
# removed_columns_count 25
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  0 1 69 1.0000000000000002
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  0 3 69 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 6 69 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 7 69 1.0000000000000002
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  6 5 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  13 4 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  11 2 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  3 3 69 1.0
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  10 6 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  22 0 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  4 6 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  16 0 15 1.0
# removed_columns_count 17
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  7 8 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  22 1 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  16 1 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  19 1 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  16 3 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  16 5 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  19 2 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  16 6 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  19 3 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  6 6 39 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  16 11 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  1 1 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  11 4 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  11 6 69 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  11 7 69 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  21 7 69 0.9999999999999999
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  8 0 69 0.9999999999999998
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  8 7 69 0.9999999999999998
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  17 2 21 0.9999999999999954
# removed_columns_count 7
# GAP # iterations : 1 master obj val : 8052.111053260888
# n_most,u_most,i_most,z_most =  17 3 69 0.9999999999999954
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  17 7 21 0.9999999999999954
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  0 8 36 0.994399175369917
# removed_columns_count 11
# GAP # iterations : 1 master obj val : 8052.111496724535
# n_most,u_most,i_most,z_most =  21 4 12 0.9659863945578231
# removed_columns_count 21
# GAP # iterations : 1 master obj val : 8052.12091706758
# n_most,u_most,i_most,z_most =  22 2 23 1.0
# removed_columns_count 11
# GAP # iterations : 1 master obj val : 8052.12091706758
# n_most,u_most,i_most,z_most =  20 5 30 0.9487458174242672
# removed_columns_count 21
# GAP # iterations : 1 master obj val : 8052.140229627319
# n_most,u_most,i_most,z_most =  2 4 2 0.9765942744615355
# removed_columns_count 20
# GAP # iterations : 2 master obj val : 8051.621973908879
# n_most,u_most,i_most,z_most =  3 1 8 0.996921096762434
# removed_columns_count 19
# GAP # iterations : 1 master obj val : 8051.622275135996
# n_most,u_most,i_most,z_most =  3 5 16 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  6 4 36 0.9713331193981298
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 8051.627865773695
# n_most,u_most,i_most,z_most =  12 5 35 0.949650575619472
# removed_columns_count 17
# GAP # iterations : 2 master obj val : 8051.682388378953
# n_most,u_most,i_most,z_most =  10 7 29 0.9315118117047311
# removed_columns_count 12
# GAP # iterations : 1 master obj val : 8051.684835600341
# n_most,u_most,i_most,z_most =  2 2 11 0.9157934788784599
# removed_columns_count 5
# GAP # iterations : 1 master obj val : 8051.74469228685
# n_most,u_most,i_most,z_most =  2 3 43 0.9131196996308301
# removed_columns_count 2
# GAP # iterations : 2 master obj val : 8051.686269958432
# n_most,u_most,i_most,z_most =  18 6 35 0.9352057855747675
# removed_columns_count 23
# GAP # iterations : 1 master obj val : 8051.8329940698195
# n_most,u_most,i_most,z_most =  19 5 15 0.9074430418642934
# removed_columns_count 18
# GAP # iterations : 2 master obj val : 8051.654039763182
# n_most,u_most,i_most,z_most =  21 3 13 0.9697358811772384
# removed_columns_count 4
# GAP # iterations : 1 master obj val : 8051.664913334644
# n_most,u_most,i_most,z_most =  10 5 38 1.0
# removed_columns_count 3
# GAP # iterations : 1 master obj val : 8051.664913334644
# n_most,u_most,i_most,z_most =  21 1 45 0.9272887977940238
# removed_columns_count 3
# GAP # iterations : 2 master obj val : 8051.491854058261
# n_most,u_most,i_most,z_most =  21 2 22 1.0
# removed_columns_count 1
# GAP # iterations : 1 master obj val : 8051.491854058265
# n_most,u_most,i_most,z_most =  17 4 20 0.9955129801162879
# removed_columns_count 21
# GAP # iterations : 1 master obj val : 8051.4929798479825
# n_most,u_most,i_most,z_most =  14 2 40 0.9498411199860874
# removed_columns_count 24
# GAP # iterations : 1 master obj val : 8051.667060803675
# n_most,u_most,i_most,z_most =  14 3 40 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  14 4 9 1.0
# removed_columns_count 0
# n_most,u_most,i_most,z_most =  13 6 22 0.9403597839503443
# removed_columns_count 22
# GAP # iterations : 1 master obj val : 8051.692697768355
# n_most,u_most,i_most,z_most =  4 2 18 0.900942383926902
# removed_columns_count 22
# GAP # iterations : 2 master obj val : 8051.6026872340335
# n_most,u_most,i_most,z_most =  20 1 35 0.8413748580447101
# removed_columns_count 4
# GAP # iterations : 2 master obj val : 8052.059518103189
# n_most,u_most,i_most,z_most =  20 2 33 0.997863232662191
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 8052.062296649607
# n_most,u_most,i_most,z_most =  17 6 24 0.975
# removed_columns_count 3
# GAP # iterations : 2 master obj val : 8051.99568047293
# n_most,u_most,i_most,z_most =  20 4 31 0.9551682068404513
# removed_columns_count 2
# GAP # iterations : 1 master obj val : 8052.00527948528
# n_most,u_most,i_most,z_most =  16 9 30 0.9071816944181642
# removed_columns_count 10
# GAP # iterations : 1 master obj val : 8052.340385692667
# n_most,u_most,i_most,z_most =  5 3 26 0.8447368679624367
# removed_columns_count 27
# GAP # iterations : 2 master obj val : 8052.355458670628
# ... solving restricted compact model
# 531.517 result (0.1716611385345459, 'INFEASIBLE', 1.0, None, None)
#
# --------------------------------------------------------------------------------
